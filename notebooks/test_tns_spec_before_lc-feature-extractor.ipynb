# %%
from collections import OrderedDict, Counter
import time
import sys
import os
import antares_client
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

plt.style.use('fig_publication.mplstyle')
# %config InlineBackend.figure_format = 'retina'  #for MacOS, make plots crisp

# %%
# From 106 available features from Kostya's lc_feature_extractor, use the 82 from SNAD Miner paper 
# R and g bands
feature_names_r_g = ['feature_amplitude_magn_r', 
                         'feature_anderson_darling_normal_magn_r',
                         'feature_beyond_1_std_magn_r', 
                         'feature_beyond_2_std_magn_r',
                         'feature_cusum_magn_r', 
                         #'feature_eta_e_magn_r',
                         'feature_inter_percentile_range_2_magn_r',
                         'feature_inter_percentile_range_10_magn_r',
                         'feature_inter_percentile_range_25_magn_r', 
                         'feature_kurtosis_magn_r',
                         'feature_linear_fit_slope_magn_r',
                         'feature_linear_fit_slope_sigma_magn_r',
                         #'feature_linear_fit_reduced_chi2_magn_r', 
                         #'feature_linear_trend_magn_r', # cadence removal
                         #'feature_linear_trend_sigma_magn_r',  # cadence removal
                         'feature_magnitude_percentage_ratio_40_5_magn_r',
                         'feature_magnitude_percentage_ratio_20_5_magn_r',
                         #'feature_maximum_slope_magn_r',
                         'feature_mean_magn_r',
                         'feature_median_absolute_deviation_magn_r',
                         'feature_percent_amplitude_magn_r',
                         'feature_median_buffer_range_percentage_10_magn_r',
                         'feature_median_buffer_range_percentage_20_magn_r',
                         'feature_percent_difference_magnitude_percentile_5_magn_r',
                         'feature_percent_difference_magnitude_percentile_10_magn_r',
                         #'feature_period_0_magn_r',  # should be negated
                         #'feature_period_s_to_n_0_magn_r', # cadence removal
                         #'feature_period_1_magn_r', 
                         #'feature_period_s_to_n_1_magn_r', # cadence removal
                         #'feature_period_2_magn_r', 
                         #'feature_period_s_to_n_2_magn_r', # cadence removal
                         #'feature_period_3_magn_r', 
                         #'feature_period_s_to_n_3_magn_r', # cadence removal
                         #'feature_period_4_magn_r', 
                         #'feature_period_s_to_n_4_magn_r', # cadence removal
                         #'feature_periodogram_amplitude_magn_r',
                         #'feature_periodogram_beyond_2_std_magn_r',  # cadence removal
                         #'feature_periodogram_beyond_3_std_magn_r',  # cadence removal
                         #'feature_periodogram_standard_deviation_magn_r',   # cadence removal
                         #'feature_chi2_magn_r',
                         'feature_skew_magn_r', 
                         'feature_standard_deviation_magn_r',
                         'feature_stetson_k_magn_r',
                         'feature_weighted_mean_magn_r',
                         'feature_anderson_darling_normal_flux_r', 
                         'feature_cusum_flux_r',
                         #'feature_eta_e_flux_r', 
                         'feature_excess_variance_flux_r',
                         'feature_kurtosis_flux_r', 
                         'feature_mean_variance_flux_r',
                         #'feature_chi2_flux_r', 
                         'feature_skew_flux_r',
                         'feature_stetson_k_flux_r',

                         'feature_amplitude_magn_g', 
                         'feature_anderson_darling_normal_magn_g',
                         'feature_beyond_1_std_magn_g', 
                         'feature_beyond_2_std_magn_g',
                         'feature_cusum_magn_g', 
                         #'feature_eta_e_magn_g',
                         'feature_inter_percentile_range_2_magn_g',
                         'feature_inter_percentile_range_10_magn_g',
                         'feature_inter_percentile_range_25_magn_g', 
                         'feature_kurtosis_magn_g',
                         'feature_linear_fit_slope_magn_g',
                         'feature_linear_fit_slope_sigma_magn_g',
                         #'feature_linear_fit_reduced_chi2_magn_g', 
                         #'feature_linear_trend_magn_g', # cadence removal
                         #'feature_linear_trend_sigma_magn_g',  # cadence removal
                         'feature_magnitude_percentage_ratio_40_5_magn_g',
                         'feature_magnitude_percentage_ratio_20_5_magn_g',
                         #'feature_maximum_slope_magn_g', 
                         'feature_mean_magn_g',
                         'feature_median_absolute_deviation_magn_g',
                         'feature_median_buffer_range_percentage_10_magn_g',
                         'feature_median_buffer_range_percentage_20_magn_g',
                         'feature_percent_amplitude_magn_g',
                         'feature_percent_difference_magnitude_percentile_5_magn_g',
                         'feature_percent_difference_magnitude_percentile_10_magn_g',
                         #'feature_period_0_magn_g',  # should be negated
                         #'feature_period_s_to_n_0_magn_g', # cadence removal
                         #'feature_period_1_magn_g', 
                         #'feature_period_s_to_n_1_magn_g', # cadence removal
                         #'feature_period_2_magn_g', 
                         #'feature_period_s_to_n_2_magn_g', # cadence removal
                         #'feature_period_3_magn_g', 
                         #'feature_period_s_to_n_3_magn_g', # cadence removal
                         #'feature_period_4_magn_g', 
                         #'feature_period_s_to_n_4_magn_g', # cadence removal
                         #'feature_periodogram_amplitude_magn_g',
                         #'feature_periodogram_beyond_2_std_magn_g',  # cadence removal
                         #'feature_periodogram_beyond_3_std_magn_g', # cadence removal
                         #'feature_periodogram_standard_deviation_magn_g',  # cadence removal
                         #'feature_chi2_magn_g',
                         'feature_skew_magn_g', 
                         'feature_standard_deviation_magn_g',
                         'feature_stetson_k_magn_g', 
                         'feature_weighted_mean_magn_g',
                         'feature_anderson_darling_normal_flux_g', 
                         'feature_cusum_flux_g',
                         #'feature_eta_e_flux_g', 
                         'feature_excess_variance_flux_g',
                         'feature_kurtosis_flux_g', 
                         'feature_mean_variance_flux_g',
                         #'feature_chi2_flux_g', 
                         'feature_skew_flux_g',
                         'feature_stetson_k_flux_g'] 
    
ztf_id_and_features_r_g = ['Unnamed: 0'] + ['locus_id', 'ra', 'dec',\
                            'tags', 'catalogs', 'ztf_object_id', 'ztf_ssnamenr', 'num_alerts',\
                            'num_mag_values', 'oldest_alert_id', 'oldest_alert_magnitude',\
                            'oldest_alert_observation_time', 'newest_alert_id',\
                            'newest_alert_magnitude', 'newest_alert_observation_time',\
                            'brightest_alert_id', 'brightest_alert_magnitude', \
                            'brightest_alert_observation_time'] + feature_names_r_g +\
                        ['horizons_targetname', 'anomaly', 'anom_score', 'anomaly_score',\
                         'anomaly_mask', 'anomaly_type', 'is_corrected', 'vpdf_extreme_version',\
                         'vpdf_extreme_faint', 'vpdf_extreme_bright', 'locus_gal_l', 'locus_gal_b']


feature_names_hostgal = [
#  'Unnamed: 0',
#  'level_0',
#  'index',
#  'objName',
#  'objAltName1',
#  'objAltName2',
#  'objAltName3',
#  'objID',
#  'uniquePspsOBid',
#  'ippObjID',
#  'surveyID',
#  'htmID',
#  'zoneID',
#  'tessID',
#  'projectionID',
#  'skyCellID',
#  'randomID',
#  'batchID',
#  'dvoRegionID',
#  'processingVersion',
#  'objInfoFlag',
#  'qualityFlag',
#  'raStack',
#  'decStack',
#  'raStackErr',
#  'decStackErr',
#  'raMean',
#  'decMean',
#  'raMeanErr',
#  'decMeanErr',
#  'epochMean',
#  'posMeanChisq',
#  'cx',
#  'cy',
#  'cz',
#  'lambda',
#  'beta',
#  'l',
#  'b',
#  'nStackObjectRows',
#  'nStackDetections',
#  'nDetections',
#  'ng',
#  'nr',
#  'ni',
#  'nz',
#  'ny',
#  'uniquePspsSTid',
#  'primaryDetection',
#  'bestDetection',
#  'gippDetectID',
#  'gstackDetectID',
#  'gstackImageID',
#  'gra',
#  'gdec',
#  'graErr',
#  'gdecErr',
#  'gEpoch',
#  'gPSFMag',
#  'gPSFMagErr',
#  'gApMag',
#  'gApMagErr',
#  'gKronMag',
#  'gKronMagErr',
#  'ginfoFlag',
#  'ginfoFlag2',
#  'ginfoFlag3',
#  'gnFrames',
#  'gxPos',
#  'gyPos',
#  'gxPosErr',
#  'gyPosErr',
#  'gpsfMajorFWHM',
#  'gpsfMinorFWHM',
#  'gpsfTheta',
#  'gpsfCore',
#  'gpsfLikelihood',
#  'gpsfQf',
#  'gpsfQfPerfect',
#  'gpsfChiSq',
 'gmomentXX',
 'gmomentXY',
 'gmomentYY',
 'gmomentR1',
 'gmomentRH',
 'gPSFFlux',
#  'gPSFFluxErr',
 'gApFlux',
#  'gApFluxErr',
#  'gApFillFac',
#  'gApRadius',
 'gKronFlux',
#  'gKronFluxErr',
 'gKronRad',
#  'gexpTime',
 'gExtNSigma',
#  'gsky',
#  'gskyErr',
#  'gzp',
#  'gPlateScale',
#  'rippDetectID',
#  'rstackDetectID',
#  'rstackImageID',
#  'rra',
#  'rdec',
#  'rraErr',
#  'rdecErr',
#  'rEpoch',
# 'rPSFMag',
#  'rPSFMagErr',
# 'rApMag',
#  'rApMagErr',
# 'rKronMag',
#  'rKronMagErr',
#  'rinfoFlag',
#  'rinfoFlag2',
#  'rinfoFlag3',
#  'rnFrames',
#  'rxPos',
#  'ryPos',
#  'rxPosErr',
#  'ryPosErr',
#  'rpsfMajorFWHM',
#  'rpsfMinorFWHM',
#  'rpsfTheta',
#  'rpsfCore',
#  'rpsfLikelihood',
#  'rpsfQf',
#  'rpsfQfPerfect',
#  'rpsfChiSq',
 'rmomentXX',
 'rmomentXY',
 'rmomentYY',
 'rmomentR1',
 'rmomentRH',
'rPSFFlux',
#  'rPSFFluxErr',
'rApFlux',
#  'rApFluxErr',
#  'rApFillFac',
# 'rApRadius',
'rKronFlux',
#  'rKronFluxErr',
'rKronRad',
#  'rexpTime',
 'rExtNSigma',
#  'rsky',
#  'rskyErr',
#  'rzp',
#  'rPlateScale',
#  'iippDetectID',
#  'istackDetectID',
#  'istackImageID',
#  'ira',
#  'idec',
#  'iraErr',
#  'idecErr',
#  'iEpoch',
#  'iPSFMag',
#  'iPSFMagErr',
#  'iApMag',
#  'iApMagErr',
#  'iKronMag',
#  'iKronMagErr',
#  'iinfoFlag',
#  'iinfoFlag2',
#  'iinfoFlag3',
#  'inFrames',
#  'ixPos',
#  'iyPos',
#  'ixPosErr',
#  'iyPosErr',
#  'ipsfMajorFWHM',
#  'ipsfMinorFWHM',
#  'ipsfTheta',
#  'ipsfCore',
#  'ipsfLikelihood',
#  'ipsfQf',
#  'ipsfQfPerfect',
#  'ipsfChiSq',
  'imomentXX',
 'imomentXY',
 'imomentYY',
 'imomentR1',
 'imomentRH',
 'iPSFFlux',
#  'iPSFFluxErr',
 'iApFlux',
#  'iApFluxErr',
#  'iApFillFac',
#  'iApRadius',
 'iKronFlux',
#  'iKronFluxErr',
 'iKronRad',
#  'iexpTime',
  'iExtNSigma',
#  'isky',
#  'iskyErr',
#  'izp',
#  'iPlateScale',
#  'zippDetectID',
#  'zstackDetectID',
#  'zstackImageID',
#  'zra',
#  'zdec',
#  'zraErr',
#  'zdecErr',
#  'zEpoch',
#  'zPSFMag',
#  'zPSFMagErr',
#  'zApMag',
#  'zApMagErr',
#  'zKronMag',
#  'zKronMagErr',
#  'zinfoFlag',
#  'zinfoFlag2',
#  'zinfoFlag3',
#  'znFrames',
#  'zxPos',
#  'zyPos',
#  'zxPosErr',
#  'zyPosErr',
#  'zpsfMajorFWHM',
#  'zpsfMinorFWHM',
#  'zpsfTheta',
#  'zpsfCore',
#  'zpsfLikelihood',
#  'zpsfQf',
#  'zpsfQfPerfect',
#  'zpsfChiSq',
  'zmomentXX',
 'zmomentXY',
 'zmomentYY',
 'zmomentR1',
 'zmomentRH',
 'zPSFFlux',
# #  'zPSFFluxErr',
 'zApFlux',
# #  'zApFluxErr',
# #  'zApFillFac',
# #  'zApRadius',
 'zKronFlux',
# #  'zKronFluxErr',
 'zKronRad',
# #  'zexpTime',
  'zExtNSigma',
#  'zsky',
#  'zskyErr',
#  'zzp',
#  'zPlateScale',
#  'yippDetectID',
#  'ystackDetectID',
#  'ystackImageID',
#  'yra',
#  'ydec',
#  'yraErr',
#  'ydecErr',
#  'yEpoch',
#  'yPSFMag',
#  'yPSFMagErr',
#  'yApMag',
#  'yApMagErr',
#  'yKronMag',
#  'yKronMagErr',
#  'yinfoFlag',
#  'yinfoFlag2',
#  'yinfoFlag3',
#  'ynFrames',
#  'yxPos',
#  'yyPos',
#  'yxPosErr',
#  'yyPosErr',
#  'ypsfMajorFWHM',
#  'ypsfMinorFWHM',
#  'ypsfTheta',
#  'ypsfCore',
#  'ypsfLikelihood',
#  'ypsfQf',
#  'ypsfQfPerfect',
#  'ypsfChiSq',
  'ymomentXX',
  'ymomentXY',
  'ymomentYY',
  'ymomentR1',
  'ymomentRH',
  'yPSFFlux',
# #   'yPSFFluxErr',
  'yApFlux',
# #   'yApFluxErr',
# #   'yApFillFac',
# #  'yApRadius',
 'yKronFlux',
# #  'yKronFluxErr',
 'yKronRad',
# #  'yexpTime',
  'yExtNSigma',
#  'ysky',
#  'yskyErr',
#  'yzp',
#  'yPlateScale',
#  'distance',
#  'SkyMapper_StarClass',
#  'gelong',
#  'g_a',
#  'g_b',
#  'g_pa',
#  'relong',
#  'r_a',
#  'r_b',
#  'r_pa',
#  'ielong',
#  'i_a',
#  'i_b',
#  'i_pa',
#  'zelong',
#  'z_a',
#  'z_b',
#  'z_pa',
   'i-z', # try throwing in
#    'g-r',
#    'r-i',
#    'g-i',
#    'z-y',
#   'g-rErr',
#   'r-iErr',
#   'i-zErr',
#   'z-yErr',
 'gApMag_gKronMag',
 'rApMag_rKronMag',
 'iApMag_iKronMag',
 'zApMag_zKronMag',
 'yApMag_yKronMag',
 '7DCD', 
#  'NED_name',
#  'NED_type',
#  'NED_vel',
#  'NED_redshift',
#  'NED_mag',
#  'class',
   'dist/DLR',
#   'dist',
#  'TransientClass',
#  'TransientRA',
#  'TransientDEC'
   ]

feature_names_tns = ['has_tns', 'tns_cls', 'spec_z', 'report_group']

lc_and_host_features = feature_names_r_g+feature_names_hostgal
lc_and_host_and_tns_features = lc_and_host_features + feature_names_tns

# %%
def plot_conf_matrix(y_test, y_pred, labels, title, kind, figsize=(6, 4)):
    if kind == 'completeness':
        counts = confusion_matrix(y_test, y_pred, labels=labels, normalize=None)
        recall = confusion_matrix(y_test, y_pred, labels=labels, normalize='true')
        annotations = np.vectorize(lambda c, r: f'{r:.2g}\n({c})')(counts, recall)
        heatmap = pd.DataFrame(recall, index=labels, columns=labels)
    
    if kind == 'purity':
        counts = confusion_matrix(y_test, y_pred, labels=labels, normalize=None)
        recall = confusion_matrix(y_test, y_pred, labels=labels, normalize='pred')
        annotations = np.vectorize(lambda c, r: f'{r:.2g}\n({c})')(counts, recall)
        heatmap = pd.DataFrame(recall, index=labels, columns=labels)
    
    plt.figure(figsize=figsize)
    sns.heatmap(heatmap, annot=annotations, fmt='s', cmap='Blues', vmin=0, vmax=1, annot_kws={"fontsize":18})
    plt.title(title, fontsize=24)
    plt.ylabel('True class', fontsize=24)
    plt.xlabel('Predicted class', fontsize=24)
    #plt.show()

# %%
def plot_RFC_prob_vs_lc(dataframe, anom_thresh):
    import antares_client

    df_path = "/Users/patrickaleo/Desktop/Illinois/LAISS-antares/repo/CVAE_dataframes"
    anom_thresh = anom_thresh

    num_anom_epochs_l = []
    anom_ztfid_l, tnscls_l = [],[]
    for anom_ztfid, tnscls in zip(dataframe.index, dataframe.tns_cls):
        print(anom_ztfid, tnscls)
        try:
            lc_and_hosts_df = pd.read_csv(f'{df_path}/{anom_ztfid}_timeseries.csv')
        except:
            print(f"couldn't feature space as func of time for {anom_ztfid}. Make anom epoch -9")
            num_anom_epochs_l.append(-9)
            continue

        lc_and_hosts_df = lc_and_hosts_df.dropna()
        anom_obj_df = lc_and_hosts_df[x_test.columns]

        
        try:
            pred_prob_anom = 100 * clf.predict_proba(anom_obj_df)
            num_anom_epochs = len(np.where(pred_prob_anom[:, 1]>=anom_thresh)[0])
            num_anom_epochs_l.append(num_anom_epochs)
        except:
            print(f"{anom_ztfid} has some NaN host galaxy values from PS1 catalog. Skip!")
            continue

        try: 
            #anom_idx = np.where(pred_prob_anom[:, 1]>=50)[0][0]
            orig = pd.read_csv(f'{df_path}/{anom_ztfid}_timeseries.csv')
            diff = len(orig)-len(pred_prob_anom)
            #if len(np.where(pred_prob_anom[:, 1]>=anom_thresh)) == 1:
            if not np.where(pred_prob_anom[:, 1]>=anom_thresh)[0][0] == 0:
                anom_idx = lc_and_hosts_df.loc[np.where(pred_prob_anom[:, 1]>=anom_thresh)[0][0]].obs_num + diff
            else: anom_idx = lc_and_hosts_df.iloc[np.where(pred_prob_anom[:, 1]>=anom_thresh)[0][0]].obs_num + diff
            anom_idx_is = True

        except: 
            print(f"Prediction doesn't exceed anom_threshold of {anom_thresh}% for {anom_ztfid}.")
            anom_idx_is = False

        ztf_id_ref = anom_ztfid 

        ref_info = antares_client.search.get_by_ztf_object_id(ztf_object_id=ztf_id_ref)

        try: df_ref = ref_info.timeseries.to_pandas()
        except: 
            print(f"No ref_info.timeseries.to_pandas() for {anom_ztfid}. Continue...")
            continue

        print(num_anom_epochs)
        anom_ztfid_l.append(anom_ztfid), tnscls_l.append(tnscls)

        df_ref_g = df_ref[(df_ref.ant_passband == 'g') & (~df_ref.ant_mag.isna())]
        df_ref_r = df_ref[(df_ref.ant_passband == 'R') & (~df_ref.ant_mag.isna())]

        mjd_idx_at_min_mag_r_ref = df_ref_r[['ant_mag']].reset_index().idxmin().ant_mag
        mjd_idx_at_min_mag_g_ref = df_ref_g[['ant_mag']].reset_index().idxmin().ant_mag

        fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(7,10))
        ax1.invert_yaxis()
        ax1.errorbar(x=df_ref_r.ant_mjd, y=df_ref_r.ant_mag, yerr=df_ref_r.ant_magerr, fmt='o', c='r', 
                    label=f'REF: {ztf_id_ref}')
        ax1.errorbar(x=df_ref_g.ant_mjd, y=df_ref_g.ant_mag, yerr=df_ref_g.ant_magerr, fmt='o', c='g')
        #ax1.axvline(x=lc_and_hosts_df.loc[lc_and_hosts_df.loc[anom_idx].obs_num].mjd_cutoff)
        if anom_idx_is == True:
            ax1.axvline(x=lc_and_hosts_df[lc_and_hosts_df.obs_num == anom_idx].mjd_cutoff.values[0])
        #ax1.set_xlim(min(df_ref_r.ant_mjd), max(df_ref_r.ant_mjd))
        ax1.set_ylabel('Mag')


        print(f'https://alerce.online/object/{anom_ztfid}', tnscls)
        ax2.plot(lc_and_hosts_df['mjd_cutoff'], pred_prob_anom[:, 0], label='p(Normal)')
        ax2.plot(lc_and_hosts_df['mjd_cutoff'], pred_prob_anom[:, 1], label='p(Other)')
        #ax2.axhline(y=50)

        ax2.set_ylabel('Probability (%)')


        #ax2.set_xlim(min(df_ref_r.ant_mjd), max(df_ref_r.ant_mjd))

        plt.xlabel('mjd_cutoff')
        plt.legend()
        plt.show()
        
def plot_RFC_prob_vs_lc_ztfid(anom_ztfid, anom_thresh, df_path):
    # Predict Excluded Object
    import antares_client
    
    df_path = df_path
    anom_thresh = anom_thresh

    try:
        lc_and_hosts_df = pd.read_csv(f'{df_path}/{anom_ztfid}_timeseries.csv')
    except:
        print(f"couldn't feature space as func of time for {anom_ztfid}. pass.")
        pass

    lc_and_hosts_df = lc_and_hosts_df.dropna()
    anom_obj_df = lc_and_hosts_df[x_test.columns]

    try:
        pred_prob_anom = 100 * clf.predict_proba(anom_obj_df)
        num_anom_epochs = len(np.where(pred_prob_anom[:, 1]>=anom_thresh)[0])
    except:
        print(f"{anom_ztfid} has some NaN host galaxy values from PS1 catalog. Skip!")
        return

    try: 
        #anom_idx = np.where(pred_prob_anom[:, 1]>=50)[0][0]
        orig = pd.read_csv(f'{df_path}/{anom_ztfid}_timeseries.csv')
        diff = len(orig)-len(pred_prob_anom)
        anom_idx = lc_and_hosts_df.loc[np.where(pred_prob_anom[:, 1]>=anom_thresh)[0][0]].obs_num + diff
        anom_idx_is = True

    except: 
        print(f"Prediction doesn't exceed anom_threshold of {anom_thresh}% for {anom_ztfid}.")
        anom_idx_is = False
    
    ztf_id_ref = anom_ztfid 

    ref_info = antares_client.search.get_by_ztf_object_id(ztf_object_id=ztf_id_ref)

    df_ref = ref_info.timeseries.to_pandas()

    df_ref_g = df_ref[(df_ref.ant_passband == 'g') & (~df_ref.ant_mag.isna())]
    df_ref_r = df_ref[(df_ref.ant_passband == 'R') & (~df_ref.ant_mag.isna())]

    mjd_idx_at_min_mag_r_ref = df_ref_r[['ant_mag']].reset_index().idxmin().ant_mag
    mjd_idx_at_min_mag_g_ref = df_ref_g[['ant_mag']].reset_index().idxmin().ant_mag

    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(7,10))
    ax1.invert_yaxis()
    ax1.errorbar(x=df_ref_r.ant_mjd, y=df_ref_r.ant_mag, yerr=df_ref_r.ant_magerr, fmt='o', c='r', 
                label=f'REF: {ztf_id_ref}')
    ax1.errorbar(x=df_ref_g.ant_mjd, y=df_ref_g.ant_mag, yerr=df_ref_g.ant_magerr, fmt='o', c='g')
    if anom_idx_is == True:
        ax1.axvline(x=lc_and_hosts_df[lc_and_hosts_df.obs_num == anom_idx].mjd_cutoff.values[0])
    #ax1.set_xlim(min(df_ref_r.ant_mjd), max(df_ref_r.ant_mjd))

    print(f'https://alerce.online/object/{anom_ztfid}')
    ax2.plot(lc_and_hosts_df['mjd_cutoff'], pred_prob_anom[:, 0], label='p(Normal)')
    ax2.plot(lc_and_hosts_df['mjd_cutoff'], pred_prob_anom[:, 1], label='p(Other)')
    #ax2.axhline(y=50)

    #ax2.set_xlim(min(df_ref_r.ant_mjd), max(df_ref_r.ant_mjd))

    plt.xlabel('mjd_cutoff')
    plt.ylabel('Probability (%)')
    plt.legend()
    plt.show()

# %%
dfs = []
for idx in range(1, 57):
    df = pd.read_csv(f'../tables/before_lc-feature-extractor_tns_search/{idx}_of_56.csv', index_col=0)
    dfs.append(df)
    
all_tns_result_df = pd.concat(dfs, axis=0).reset_index(drop=True)
all_tns_result_df.to_csv('../tables/before_lc-feature-extractor_tns_search_2778spec.csv', index=False)
all_tns_result_df
# Out:
#              Name            RA           DEC          Obj. Type  Redshift  \
# 0     SN 2020aewj  17:41:43.138  +67:57:42.59              SN Ia  0.055000
# 1     SN 2020abjx  02:15:02.300  -08:37:43.70             SLSN-I  0.390000
# 2      SN 2020zct  06:32:50.530  -12:23:00.56  SN Iax[02cx-like]  0.140000
# 3      SN 2020vdc  02:58:54.456  -10:33:53.12              SN II  0.034400
# 4      SN 2020uyr  22:33:34.050  -20:46:01.13              SN Ia  0.067767
# ...           ...           ...           ...                ...       ...
# 2773   SN 2018aey  10:51:16.440  +22:28:39.40              SN Ia  0.077000
# 2774   SN 2018aex  11:00:45.380  +22:17:14.96              SN II  0.023000
# 2775    SN 2018yt  08:59:35.590  +45:36:41.90              SN II  0.052000
# 2776    SN 2018mg  10:56:53.580  +79:16:42.50              SN Ia  0.110000
# 2777    SN 2018mf  10:22:09.778  +10:26:24.09              SN Ia  0.107000
#
#      Host Name  Host Redshift                   Reporting Group/s  \
# 0          NaN            NaN                                 ZTF
# 1          NaN            NaN                          ZTF, ATLAS
# 2                         NaN                              REFITT
# 3          NaN            NaN              ZTF, ATLAS, Pan-STARRS
# 4          NaN            NaN  ZTF, Pan-STARRS, ATLAS, GaiaAlerts
# ...        ...            ...                                 ...
# 2773       NaN         0.0767                                 ZTF
# 2774       NaN         0.0229              ZTF, GaiaAlerts, ATLAS
# 2775       NaN            NaN                                 ZTF
# 2776       NaN            NaN                                 ZTF
# 2777       NaN            NaN                     ZTF, Pan-STARRS
#
#                  Discovery Data Source/s Classifying Group/s  ... Public  \
# 0                                    ZTF                 ZTF  ...      1
# 1                             ZTF, ATLAS                 ZTF  ...      1
# 2                                    ZTF              REFITT  ...      1
# 3                 ZTF, ATLAS, Pan-STARRS                 ZTF  ...      1
# 4     ZTF, Pan-STARRS, ATLAS, GaiaAlerts                 ZTF  ...      1
# ...                                  ...                 ...  ...    ...
# 2773                                 ZTF                 ZTF  ...      1
# 2774              ZTF, GaiaAlerts, ATLAS                 ZTF  ...      1
# 2775                                 ZTF                 ZTF  ...      1
# 2776                                 ZTF                 ZTF  ...      1
# 2777                     ZTF, Pan-STARRS                 ZTF  ...      1
#
#      End Prop. Period Discovery Mag/Flux Discovery Filter  \
# 0                 NaN            19.4900            g-ZTF
# 1                 NaN            20.7600          r-Sloan
# 2                 NaN            19.8499            g-PTF
# 3                 NaN            19.5800            g-ZTF
# 4                 NaN            20.1000            r-ZTF
# ...               ...                ...              ...
# 2773       2018-04-24            18.4000            r-ZTF
# 2774              NaN            18.1000            r-ZTF
# 2775       2018-04-24            18.9000            r-ZTF
# 2776       2018-02-07            20.1000            g-ZTF
# 2777              NaN            19.6000            g-ZTF
#
#           Discovery Date (UT)              Sender Remarks  \
# 0     2020-01-27 11:41:51.360              Goobar     NaN
# 1     2020-09-19 09:35:34.080                 Yan     NaN
# 2     2020-09-26 11:35:27.744          REFITT_BOT     NaN
# 3     2020-09-29 09:09:49.248  ZTF_AMPEL_COMPLETE     NaN
# 4     2020-09-20 08:02:24.000            ZTF_Bot1     NaN
# ...                       ...                 ...     ...
# 2773  2018-03-05 06:08:38.000            ZTF_Bot1     NaN
# 2774  2018-03-05 06:07:12.000            ZTF_Bot1     NaN
# 2775  2018-02-09 06:00:00.000            ZTF_Bot1     NaN
# 2776  2018-01-11 10:52:26.000            ZTF_Bot1     NaN
# 2777  2018-01-14 10:29:02.000            ZTF_Bot1     NaN
#
#         Discovery Bibcode Classification Bibcodes Ext. catalog/s
# 0     2021TNSTR.335....1G     2021TNSCR.341....1P            NaN
# 1     2020TNSTR3637....1Y     2020TNSCR3639....1Y            NaN
# 2     2020TNSTR3408....1W     2020TNSCR3413....1W            NaN
# 3     2020TNSTR3060....1N     2020TNSCR3640....1Y            NaN
# 4     2020TNSTR3038....1F     2020TNSCR3122....1D            NaN
# ...                   ...                     ...            ...
# 2773  2018TNSTR.545....1L     2018TNSCR.547....1N            NaN
# 2774  2018TNSTR.545....1L     2018TNSCR.547....1N            NaN
# 2775  2018TNSTR.544....1T     2018TNSCR.548....1T            NaN
# 2776  2018TNSTR.172....1L     2018TNSCR.175....1F            NaN
# 2777  2018TNSTR.172....1L     2018TNSCR.175....1F            NaN
#
# [2778 rows x 25 columns]

# %%
all_tns_result_df = pd.read_csv('../tables/before_lc-feature-extractor_tns_search_2778spec.csv', index_col=0)
all_tns_result_df
# Out:
#                        RA           DEC          Obj. Type  Redshift  \
# Name
# SN 2020aewj  17:41:43.138  +67:57:42.59              SN Ia  0.055000
# SN 2020abjx  02:15:02.300  -08:37:43.70             SLSN-I  0.390000
# SN 2020zct   06:32:50.530  -12:23:00.56  SN Iax[02cx-like]  0.140000
# SN 2020vdc   02:58:54.456  -10:33:53.12              SN II  0.034400
# SN 2020uyr   22:33:34.050  -20:46:01.13              SN Ia  0.067767
# ...                   ...           ...                ...       ...
# SN 2018aey   10:51:16.440  +22:28:39.40              SN Ia  0.077000
# SN 2018aex   11:00:45.380  +22:17:14.96              SN II  0.023000
# SN 2018yt    08:59:35.590  +45:36:41.90              SN II  0.052000
# SN 2018mg    10:56:53.580  +79:16:42.50              SN Ia  0.110000
# SN 2018mf    10:22:09.778  +10:26:24.09              SN Ia  0.107000
#
#             Host Name  Host Redshift                   Reporting Group/s  \
# Name
# SN 2020aewj       NaN            NaN                                 ZTF
# SN 2020abjx       NaN            NaN                          ZTF, ATLAS
# SN 2020zct                       NaN                              REFITT
# SN 2020vdc        NaN            NaN              ZTF, ATLAS, Pan-STARRS
# SN 2020uyr        NaN            NaN  ZTF, Pan-STARRS, ATLAS, GaiaAlerts
# ...               ...            ...                                 ...
# SN 2018aey        NaN         0.0767                                 ZTF
# SN 2018aex        NaN         0.0229              ZTF, GaiaAlerts, ATLAS
# SN 2018yt         NaN            NaN                                 ZTF
# SN 2018mg         NaN            NaN                                 ZTF
# SN 2018mf         NaN            NaN                     ZTF, Pan-STARRS
#
#                         Discovery Data Source/s Classifying Group/s  \
# Name
# SN 2020aewj                                 ZTF                 ZTF
# SN 2020abjx                          ZTF, ATLAS                 ZTF
# SN 2020zct                                  ZTF              REFITT
# SN 2020vdc               ZTF, ATLAS, Pan-STARRS                 ZTF
# SN 2020uyr   ZTF, Pan-STARRS, ATLAS, GaiaAlerts                 ZTF
# ...                                         ...                 ...
# SN 2018aey                                  ZTF                 ZTF
# SN 2018aex               ZTF, GaiaAlerts, ATLAS                 ZTF
# SN 2018yt                                   ZTF                 ZTF
# SN 2018mg                                   ZTF                 ZTF
# SN 2018mf                       ZTF, Pan-STARRS                 ZTF
#
#                              Associated Group/s  ... Public End Prop. Period  \
# Name                                             ...
# SN 2020aewj                                 ZTF  ...      1              NaN
# SN 2020abjx                          ATLAS; ZTF  ...      1              NaN
# SN 2020zct                          REFITT; ZTF  ...      1              NaN
# SN 2020vdc               ATLAS; Pan-STARRS; ZTF  ...      1              NaN
# SN 2020uyr   ATLAS; GaiaAlerts; Pan-STARRS; ZTF  ...      1              NaN
# ...                                         ...  ...    ...              ...
# SN 2018aey                                  ZTF  ...      1       2018-04-24
# SN 2018aex               ATLAS; GaiaAlerts; ZTF  ...      1              NaN
# SN 2018yt                                   ZTF  ...      1       2018-04-24
# SN 2018mg                                   ZTF  ...      1       2018-02-07
# SN 2018mf                       Pan-STARRS; ZTF  ...      1              NaN
#
#             Discovery Mag/Flux  Discovery Filter      Discovery Date (UT)  \
# Name
# SN 2020aewj            19.4900             g-ZTF  2020-01-27 11:41:51.360
# SN 2020abjx            20.7600           r-Sloan  2020-09-19 09:35:34.080
# SN 2020zct             19.8499             g-PTF  2020-09-26 11:35:27.744
# SN 2020vdc             19.5800             g-ZTF  2020-09-29 09:09:49.248
# SN 2020uyr             20.1000             r-ZTF  2020-09-20 08:02:24.000
# ...                        ...               ...                      ...
# SN 2018aey             18.4000             r-ZTF  2018-03-05 06:08:38.000
# SN 2018aex             18.1000             r-ZTF  2018-03-05 06:07:12.000
# SN 2018yt              18.9000             r-ZTF  2018-02-09 06:00:00.000
# SN 2018mg              20.1000             g-ZTF  2018-01-11 10:52:26.000
# SN 2018mf              19.6000             g-ZTF  2018-01-14 10:29:02.000
#
#                          Sender  Remarks    Discovery Bibcode  \
# Name
# SN 2020aewj              Goobar      NaN  2021TNSTR.335....1G
# SN 2020abjx                 Yan      NaN  2020TNSTR3637....1Y
# SN 2020zct           REFITT_BOT      NaN  2020TNSTR3408....1W
# SN 2020vdc   ZTF_AMPEL_COMPLETE      NaN  2020TNSTR3060....1N
# SN 2020uyr             ZTF_Bot1      NaN  2020TNSTR3038....1F
# ...                         ...      ...                  ...
# SN 2018aey             ZTF_Bot1      NaN  2018TNSTR.545....1L
# SN 2018aex             ZTF_Bot1      NaN  2018TNSTR.545....1L
# SN 2018yt              ZTF_Bot1      NaN  2018TNSTR.544....1T
# SN 2018mg              ZTF_Bot1      NaN  2018TNSTR.172....1L
# SN 2018mf              ZTF_Bot1      NaN  2018TNSTR.172....1L
#
#             Classification Bibcodes Ext. catalog/s
# Name
# SN 2020aewj     2021TNSCR.341....1P            NaN
# SN 2020abjx     2020TNSCR3639....1Y            NaN
# SN 2020zct      2020TNSCR3413....1W            NaN
# SN 2020vdc      2020TNSCR3640....1Y            NaN
# SN 2020uyr      2020TNSCR3122....1D            NaN
# ...                             ...            ...
# SN 2018aey      2018TNSCR.547....1N            NaN
# SN 2018aex      2018TNSCR.547....1N            NaN
# SN 2018yt       2018TNSCR.548....1T            NaN
# SN 2018mg       2018TNSCR.175....1F            NaN
# SN 2018mf       2018TNSCR.175....1F            NaN
#
# [2778 rows x 24 columns]

# %%
Counter(all_tns_result_df["Obj. Type"])
# Out:
# Counter({'SN Ia': 1947,
#          'SLSN-I': 36,
#          'SN Iax[02cx-like]': 9,
#          'SN II': 342,
#          'SN Ic': 55,
#          'SLSN-II': 31,
#          'SN IIn': 79,
#          'SN Ia-91T-like': 63,
#          'SN IIb': 34,
#          'SN Ib': 42,
#          'SN IIP': 35,
#          'SN Ic-BL': 27,
#          'SN Ib/c': 10,
#          'SN Ia-pec': 16,
#          'SN Ia-CSM': 4,
#          'SN Ia-91bg-like': 11,
#          'TDE': 13,
#          'SN Ibn': 11,
#          'Afterglow': 1,
#          'SN': 2,
#          'SN Ia-Ca-rich': 1,
#          'SN Icn': 1,
#          'SN II-pec': 1,
#          'ILRT': 1,
#          'SN I': 1,
#          'SN Ib-Ca-rich': 2,
#          'SN IIL': 1,
#          'LBV': 1,
#          'LRN': 1})

# %%
all_tns_result_df["Disc. Internal Name"]
# Out:
# Name
# SN 2020aewj             NaN
# SN 2020abjx             NaN
# SN 2020zct     ZTF20acezhcf
# SN 2020vdc     ZTF20achuhlt
# SN 2020uyr     ZTF20achatyv
#                    ...
# SN 2018aey     ZTF18aabsyqp
# SN 2018aex     ZTF18aabssth
# SN 2018yt      ZTF18aaayemw
# SN 2018mg      ZTF18aaaoktp
# SN 2018mf      ZTF18aaaoaeq
# Name: Disc. Internal Name, Length: 2778, dtype: object

# %%
all_tns_result_df[all_tns_result_df["Disc. Internal Name"].isna()]
# Out:
#                        RA           DEC Obj. Type  Redshift  \
# Name
# SN 2020aewj  17:41:43.138  +67:57:42.59     SN Ia   0.05500
# SN 2020abjx  02:15:02.300  -08:37:43.70    SLSN-I   0.39000
# SN 2020ssf   23:38:40.872  +15:57:14.55     SN Ia   0.01335
# SN 2020dcn   13:45:22.580  +39:44:16.60     SN Ia   0.21770
# SN 2019aafk  22:56:20.930  +45:12:45.20    SN IIn   0.16200
# SN 2019aafj  14:48:39.800  +30:40:40.80    SN IIn   0.11300
# SN 2019aafi  22:31:58.180  +43:50:22.10    SN IIn   0.11700
# SN 2019afa   14:57:27.816  +08:47:09.03     SN Ia   0.07800
# SN 2018lua   17:05:54.580  +33:31:15.10    SN IIn   0.10100
# SN 2018hqh   10:40:33.462  +47:02:24.37     SN Ia       NaN
# SN 2018hqf   10:12:41.171  +21:24:55.45     SN Ia       NaN
#
#                             Host Name  Host Redshift Reporting Group/s  \
# Name
# SN 2020aewj                       NaN            NaN               ZTF
# SN 2020abjx                       NaN            NaN        ZTF, ATLAS
# SN 2020ssf                   NGC 7722        0.01335   ZTF, Pan-STARRS
# SN 2020dcn   SDSS J134522.58+394416.2            NaN              ZUDS
# SN 2019aafk                       NaN            NaN               ZTF
# SN 2019aafj                       NaN            NaN               ZTF
# SN 2019aafi                       NaN            NaN               ZTF
# SN 2019afa                        NaN            NaN        ZTF, ATLAS
# SN 2018lua                        NaN            NaN               ZTF
# SN 2018hqh                        NaN            NaN               ZTF
# SN 2018hqf                        NaN            NaN               ZTF
#
#             Discovery Data Source/s Classifying Group/s Associated Group/s  \
# Name
# SN 2020aewj                     ZTF                 ZTF                ZTF
# SN 2020abjx              ZTF, ATLAS                 ZTF         ATLAS; ZTF
# SN 2020ssf          ZTF, Pan-STARRS   Global SN Project    Pan-STARRS; ZTF
# SN 2020dcn                      ZTF                None                ZTF
# SN 2019aafk                     ZTF                 ZTF                ZTF
# SN 2019aafj                     ZTF                 ZTF                ZTF
# SN 2019aafi                     ZTF                 ZTF                ZTF
# SN 2019afa               ZTF, ATLAS             ePESSTO         ATLAS; ZTF
# SN 2018lua                      ZTF                 ZTF                ZTF
# SN 2018hqh                      ZTF                 ZTF                ZTF
# SN 2018hqf                      ZTF                 ZTF                ZTF
#
#              ... Public End Prop. Period Discovery Mag/Flux  Discovery Filter  \
# Name         ...
# SN 2020aewj  ...      1              NaN             19.490             g-ZTF
# SN 2020abjx  ...      1              NaN             20.760           r-Sloan
# SN 2020ssf   ...      1              NaN             17.940             i-ZTF
# SN 2020dcn   ...      1              NaN             21.200             r-ZTF
# SN 2019aafk  ...      1              NaN             20.810           r-Sloan
# SN 2019aafj  ...      1              NaN             20.810           r-Sloan
# SN 2019aafi  ...      1              NaN             19.780           r-Sloan
# SN 2019afa   ...      1              NaN             19.485             g-ZTF
# SN 2018lua   ...      1              NaN             20.340           r-Sloan
# SN 2018hqh   ...      1              NaN             19.840             r-ZTF
# SN 2018hqf   ...      1              NaN             19.750             r-ZTF
#
#                  Discovery Date (UT)     Sender  Remarks    Discovery Bibcode  \
# Name
# SN 2020aewj  2020-01-27 11:41:51.360     Goobar      NaN  2021TNSTR.335....1G
# SN 2020abjx  2020-09-19 09:35:34.080        Yan      NaN  2020TNSTR3637....1Y
# SN 2020ssf   2020-09-06 06:02:44.160         Ho      NaN  2020TNSTR2738....1H
# SN 2020dcn   2020-01-28 00:00:00.000  Goldstein      NaN  2020TNSTR.600....1G
# SN 2019aafk  2019-09-19 04:02:21.120        Yan      NaN  2020TNSTR2673....1Y
# SN 2019aafj  2019-07-27 04:06:05.760        Yan      NaN  2020TNSTR2672....1G
# SN 2019aafi  2019-04-09 12:07:20.640        Yan      NaN  2020TNSTR2672....1G
# SN 2019afa   2019-01-24 12:52:33.000     Nordin      NaN  2019TNSTR.149....1N
# SN 2018lua   2018-04-14 11:38:24.000        Yan      NaN  2020TNSTR2660....1G
# SN 2018hqh   2018-05-24 05:43:35.000         De      NaN  2018TNSTR2024....1D
# SN 2018hqf   2018-05-24 04:22:39.000         De      NaN  2018TNSTR2024....1D
#
#             Classification Bibcodes Ext. catalog/s
# Name
# SN 2020aewj     2021TNSCR.341....1P            NaN
# SN 2020abjx     2020TNSCR3639....1Y            NaN
# SN 2020ssf      2020TNSCR2763....1H            NaN
# SN 2020dcn      2022TNSCR3049....1N            NaN
# SN 2019aafk     2020TNSCR2676....1D            NaN
# SN 2019aafj     2020TNSCR2677....1Y            NaN
# SN 2019aafi     2020TNSCR2677....1Y            NaN
# SN 2019afa      2019TNSCR.159....1P            NaN
# SN 2018lua      2020TNSCR2665....1Y            NaN
# SN 2018hqh      2018TNSCR2027....1D            NaN
# SN 2018hqf      2018TNSCR2027....1D            NaN
#
# [11 rows x 24 columns]

# %%
all_tns_result_df = all_tns_result_df[~all_tns_result_df["Disc. Internal Name"].isna()]
all_tns_result_df
# Out:
#                       RA           DEC          Obj. Type  Redshift Host Name  \
# Name
# SN 2020zct  06:32:50.530  -12:23:00.56  SN Iax[02cx-like]  0.140000
# SN 2020vdc  02:58:54.456  -10:33:53.12              SN II  0.034400       NaN
# SN 2020uyr  22:33:34.050  -20:46:01.13              SN Ia  0.067767       NaN
# SN 2020uye  01:37:19.308  +04:48:07.01              SN Ia  0.060000       NaN
# SN 2020uvj  06:37:26.333  +22:39:17.82              SN Ia  0.050000       NaN
# ...                  ...           ...                ...       ...       ...
# SN 2018aey  10:51:16.440  +22:28:39.40              SN Ia  0.077000       NaN
# SN 2018aex  11:00:45.380  +22:17:14.96              SN II  0.023000       NaN
# SN 2018yt   08:59:35.590  +45:36:41.90              SN II  0.052000       NaN
# SN 2018mg   10:56:53.580  +79:16:42.50              SN Ia  0.110000       NaN
# SN 2018mf   10:22:09.778  +10:26:24.09              SN Ia  0.107000       NaN
#
#             Host Redshift                   Reporting Group/s  \
# Name
# SN 2020zct            NaN                              REFITT
# SN 2020vdc            NaN              ZTF, ATLAS, Pan-STARRS
# SN 2020uyr            NaN  ZTF, Pan-STARRS, ATLAS, GaiaAlerts
# SN 2020uye            NaN              ZTF, ATLAS, Pan-STARRS
# SN 2020uvj            NaN                          ZTF, ATLAS
# ...                   ...                                 ...
# SN 2018aey         0.0767                                 ZTF
# SN 2018aex         0.0229              ZTF, GaiaAlerts, ATLAS
# SN 2018yt             NaN                                 ZTF
# SN 2018mg             NaN                                 ZTF
# SN 2018mf             NaN                     ZTF, Pan-STARRS
#
#                        Discovery Data Source/s Classifying Group/s  \
# Name
# SN 2020zct                                 ZTF              REFITT
# SN 2020vdc              ZTF, ATLAS, Pan-STARRS                 ZTF
# SN 2020uyr  ZTF, Pan-STARRS, ATLAS, GaiaAlerts                 ZTF
# SN 2020uye              ZTF, ATLAS, Pan-STARRS                 ZTF
# SN 2020uvj                          ZTF, ATLAS                 ZTF
# ...                                        ...                 ...
# SN 2018aey                                 ZTF                 ZTF
# SN 2018aex              ZTF, GaiaAlerts, ATLAS                 ZTF
# SN 2018yt                                  ZTF                 ZTF
# SN 2018mg                                  ZTF                 ZTF
# SN 2018mf                      ZTF, Pan-STARRS                 ZTF
#
#                             Associated Group/s  ... Public End Prop. Period  \
# Name                                            ...
# SN 2020zct                         REFITT; ZTF  ...      1              NaN
# SN 2020vdc              ATLAS; Pan-STARRS; ZTF  ...      1              NaN
# SN 2020uyr  ATLAS; GaiaAlerts; Pan-STARRS; ZTF  ...      1              NaN
# SN 2020uye              ATLAS; Pan-STARRS; ZTF  ...      1              NaN
# SN 2020uvj                          ATLAS; ZTF  ...      1              NaN
# ...                                        ...  ...    ...              ...
# SN 2018aey                                 ZTF  ...      1       2018-04-24
# SN 2018aex              ATLAS; GaiaAlerts; ZTF  ...      1              NaN
# SN 2018yt                                  ZTF  ...      1       2018-04-24
# SN 2018mg                                  ZTF  ...      1       2018-02-07
# SN 2018mf                      Pan-STARRS; ZTF  ...      1              NaN
#
#            Discovery Mag/Flux  Discovery Filter      Discovery Date (UT)  \
# Name
# SN 2020zct            19.8499             g-PTF  2020-09-26 11:35:27.744
# SN 2020vdc            19.5800             g-ZTF  2020-09-29 09:09:49.248
# SN 2020uyr            20.1000             r-ZTF  2020-09-20 08:02:24.000
# SN 2020uye            20.4900             g-ZTF  2020-09-28 10:58:04.800
# SN 2020uvj            19.5600             g-ZTF  2020-10-01 10:16:19.200
# ...                       ...               ...                      ...
# SN 2018aey            18.4000             r-ZTF  2018-03-05 06:08:38.000
# SN 2018aex            18.1000             r-ZTF  2018-03-05 06:07:12.000
# SN 2018yt             18.9000             r-ZTF  2018-02-09 06:00:00.000
# SN 2018mg             20.1000             g-ZTF  2018-01-11 10:52:26.000
# SN 2018mf             19.6000             g-ZTF  2018-01-14 10:29:02.000
#
#                         Sender  Remarks    Discovery Bibcode  \
# Name
# SN 2020zct          REFITT_BOT      NaN  2020TNSTR3408....1W
# SN 2020vdc  ZTF_AMPEL_COMPLETE      NaN  2020TNSTR3060....1N
# SN 2020uyr            ZTF_Bot1      NaN  2020TNSTR3038....1F
# SN 2020uye            ZTF_Bot1      NaN  2020TNSTR3030....1F
# SN 2020uvj            ZTF_Bot1      NaN  2020TNSTR3019....1F
# ...                        ...      ...                  ...
# SN 2018aey            ZTF_Bot1      NaN  2018TNSTR.545....1L
# SN 2018aex            ZTF_Bot1      NaN  2018TNSTR.545....1L
# SN 2018yt             ZTF_Bot1      NaN  2018TNSTR.544....1T
# SN 2018mg             ZTF_Bot1      NaN  2018TNSTR.172....1L
# SN 2018mf             ZTF_Bot1      NaN  2018TNSTR.172....1L
#
#            Classification Bibcodes Ext. catalog/s
# Name
# SN 2020zct     2020TNSCR3413....1W            NaN
# SN 2020vdc     2020TNSCR3640....1Y            NaN
# SN 2020uyr     2020TNSCR3122....1D            NaN
# SN 2020uye     2020TNSCR3051....1D            NaN
# SN 2020uvj     2020TNSCR3138....1D            NaN
# ...                            ...            ...
# SN 2018aey     2018TNSCR.547....1N            NaN
# SN 2018aex     2018TNSCR.547....1N            NaN
# SN 2018yt      2018TNSCR.548....1T            NaN
# SN 2018mg      2018TNSCR.175....1F            NaN
# SN 2018mf      2018TNSCR.175....1F            NaN
#
# [2767 rows x 24 columns]

# %% [markdown]
# ## Cut on which objects are still tagged by lc_feature_extractor Filter

# %%
# %%time

ztfid_keep_l = []
for i, ztfid in enumerate(list(all_tns_result_df["Disc. Internal Name"])):
    if i % 500 == 0: print(i)
    locus = antares_client.search.get_by_ztf_object_id(ztf_object_id=ztfid)
    if locus is not None:
        if "lc_feature_extractor" not in locus.tags:
            ztfid_keep_l.append(ztfid)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# CPU times: user 1min 15s, sys: 5.41 s, total: 1min 20s
# Wall time: 4min 36s

# %%
keep_tns_result_df = all_tns_result_df[all_tns_result_df["Disc. Internal Name"].isin(ztfid_keep_l)]
keep_tns_result_df
# Out:
#                       RA           DEC          Obj. Type  Redshift  \
# Name
# SN 2020zct  06:32:50.530  -12:23:00.56  SN Iax[02cx-like]  0.140000
# SN 2020uma  22:28:50.948  +44:38:05.12              SN Ia  0.076000
# SN 2020ule  01:01:01.907  +21:11:57.54              SN Ia  0.110000
# SN 2020ugv  01:53:30.936  +01:33:26.12              SN Ia  0.100000
# SN 2020uea  02:31:21.169  +43:27:53.25              SN Ia  0.019544
# ...                  ...           ...                ...       ...
# SN 2018bxr  13:38:47.280  +30:57:34.50              SN Ia  0.064000
# SN 2018bsu  16:45:32.218  +59:55:07.05              SN Ia  0.080000
# SN 2018bij  10:20:21.072  +29:24:45.49              SN Ia  0.081100
# SN 2018bgq  15:12:44.551  +40:06:35.73              SN Ia  0.062200
# SN 2018bas  11:51:11.452  +16:31:47.45              SN II  0.066000
#
#                            Host Name  Host Redshift  \
# Name
# SN 2020zct                                      NaN
# SN 2020uma                       NaN            NaN
# SN 2020ule                       NaN            NaN
# SN 2020ugv  SDSS J015331.03+013324.4       0.068000
# SN 2020uea              CGCG 539-037       0.019544
# ...                              ...            ...
# SN 2018bxr                       NaN            NaN
# SN 2018bsu                       NaN            NaN
# SN 2018bij                       NaN            NaN
# SN 2018bgq                       NaN            NaN
# SN 2018bas                       NaN            NaN
#
#                          Reporting Group/s Discovery Data Source/s  \
# Name
# SN 2020zct                          REFITT                     ZTF
# SN 2020uma                 ZTF, Pan-STARRS         ZTF, Pan-STARRS
# SN 2020ule                      ZTF, ATLAS              ZTF, ATLAS
# SN 2020ugv                     ALeRCE, ZTF                     ZTF
# SN 2020uea  ALeRCE, ATLAS, ZTF, Pan-STARRS  ZTF, ATLAS, Pan-STARRS
# ...                                    ...                     ...
# SN 2018bxr                      ZTF, ATLAS              ZTF, ATLAS
# SN 2018bsu                             ZTF                     ZTF
# SN 2018bij                      ZTF, ATLAS              ZTF, ATLAS
# SN 2018bgq                             ZTF                     ZTF
# SN 2018bas                 ZTF, Pan-STARRS         ZTF, Pan-STARRS
#
#            Classifying Group/s      Associated Group/s  ... Public  \
# Name                                                    ...
# SN 2020zct              REFITT             REFITT; ZTF  ...      1
# SN 2020uma                 ZTF         Pan-STARRS; ZTF  ...      1
# SN 2020ule                 ZTF              ATLAS; ZTF  ...      1
# SN 2020ugv                 ZTF                     ZTF  ...      1
# SN 2020uea                 ZTF  ATLAS; Pan-STARRS; ZTF  ...      1
# ...                        ...                     ...  ...    ...
# SN 2018bxr                 ZTF              ATLAS; ZTF  ...      1
# SN 2018bsu                 ZTF                     ZTF  ...      1
# SN 2018bij                 ZTF              ATLAS; ZTF  ...      1
# SN 2018bgq                 ZTF                     ZTF  ...      1
# SN 2018bas                 ZTF         Pan-STARRS; ZTF  ...      1
#
#            End Prop. Period Discovery Mag/Flux  Discovery Filter  \
# Name
# SN 2020zct              NaN            19.8499             g-PTF
# SN 2020uma              NaN            19.8400             g-ZTF
# SN 2020ule              NaN            19.9200             g-ZTF
# SN 2020ugv              NaN            20.0451             g-ZTF
# SN 2020uea              NaN            19.1293             r-ZTF
# ...                     ...                ...               ...
# SN 2018bxr              NaN            20.0900             r-ZTF
# SN 2018bsu              NaN            19.5300             r-ZTF
# SN 2018bij              NaN            18.6900             r-ZTF
# SN 2018bgq              NaN            18.9100             r-ZTF
# SN 2018bas              NaN            19.6000             r-ZTF
#
#                 Discovery Date (UT)              Sender  Remarks  \
# Name
# SN 2020zct  2020-09-26 11:35:27.744          REFITT_BOT      NaN
# SN 2020uma  2020-09-23 06:14:24.000            ZTF_Bot1      NaN
# SN 2020ule  2020-09-27 08:07:24.672  ZTF_AMPEL_COMPLETE      NaN
# SN 2020ugv  2020-09-24 07:25:17.999              ALeRCE      NaN
# SN 2020uea  2020-09-24 09:37:11.004              ALeRCE      NaN
# ...                             ...                 ...      ...
# SN 2018bxr  2018-05-19 06:28:48.000            ZTF_Bot1      NaN
# SN 2018bsu  2018-05-14 09:20:09.000            ZTF_Bot1      NaN
# SN 2018bij  2018-05-07 03:41:45.000            ZTF_Bot1      NaN
# SN 2018bgq  2018-05-04 06:37:26.000            ZTF_Bot1      NaN
# SN 2018bas  2018-04-08 06:57:36.000            ZTF_Bot1      NaN
#
#               Discovery Bibcode Classification Bibcodes Ext. catalog/s
# Name
# SN 2020zct  2020TNSTR3408....1W     2020TNSCR3413....1W            NaN
# SN 2020uma  2020TNSTR2971....1D     2020TNSCR2973....1D            NaN
# SN 2020ule  2020TNSTR2972....1N     2020TNSCR3192....1D            NaN
# SN 2020ugv  2020TNSTR2941....1F     2020TNSCR3289....1D            NaN
# SN 2020uea  2020TNSTR2928....1F     2020TNSCR2973....1D            NaN
# ...                         ...                     ...            ...
# SN 2018bxr  2018TNSTR.705....1F     2018TNSCR1071....1F            NaN
# SN 2018bsu  2018TNSTR.658....1F     2019TNSCR.933....1F            NaN
# SN 2018bij  2018TNSTR.610....1F     2018TNSCR1071....1F            NaN
# SN 2018bgq  2018TNSTR.602....1F     2019TNSCR.892....1F            NaN
# SN 2018bas  2018TNSTR.539....1L     2018TNSCR.540....1L            NaN
#
# [2127 rows x 24 columns]

# %%
keep_tns_result_df.to_csv('../tables/before_lc-feature-extractor_tns_search_keep_2127spec.csv', index=True)

# %%
keep_tns_result_df = pd.read_csv('../tables/before_lc-feature-extractor_tns_search_keep_2127spec.csv', index_col=0)
keep_tns_result_df
# Out:
#                       RA           DEC          Obj. Type  Redshift  \
# Name
# SN 2020zct  06:32:50.530  -12:23:00.56  SN Iax[02cx-like]  0.140000
# SN 2020uma  22:28:50.948  +44:38:05.12              SN Ia  0.076000
# SN 2020ule  01:01:01.907  +21:11:57.54              SN Ia  0.110000
# SN 2020ugv  01:53:30.936  +01:33:26.12              SN Ia  0.100000
# SN 2020uea  02:31:21.169  +43:27:53.25              SN Ia  0.019544
# ...                  ...           ...                ...       ...
# SN 2018bxr  13:38:47.280  +30:57:34.50              SN Ia  0.064000
# SN 2018bsu  16:45:32.218  +59:55:07.05              SN Ia  0.080000
# SN 2018bij  10:20:21.072  +29:24:45.49              SN Ia  0.081100
# SN 2018bgq  15:12:44.551  +40:06:35.73              SN Ia  0.062200
# SN 2018bas  11:51:11.452  +16:31:47.45              SN II  0.066000
#
#                            Host Name  Host Redshift  \
# Name
# SN 2020zct                                      NaN
# SN 2020uma                       NaN            NaN
# SN 2020ule                       NaN            NaN
# SN 2020ugv  SDSS J015331.03+013324.4       0.068000
# SN 2020uea              CGCG 539-037       0.019544
# ...                              ...            ...
# SN 2018bxr                       NaN            NaN
# SN 2018bsu                       NaN            NaN
# SN 2018bij                       NaN            NaN
# SN 2018bgq                       NaN            NaN
# SN 2018bas                       NaN            NaN
#
#                          Reporting Group/s Discovery Data Source/s  \
# Name
# SN 2020zct                          REFITT                     ZTF
# SN 2020uma                 ZTF, Pan-STARRS         ZTF, Pan-STARRS
# SN 2020ule                      ZTF, ATLAS              ZTF, ATLAS
# SN 2020ugv                     ALeRCE, ZTF                     ZTF
# SN 2020uea  ALeRCE, ATLAS, ZTF, Pan-STARRS  ZTF, ATLAS, Pan-STARRS
# ...                                    ...                     ...
# SN 2018bxr                      ZTF, ATLAS              ZTF, ATLAS
# SN 2018bsu                             ZTF                     ZTF
# SN 2018bij                      ZTF, ATLAS              ZTF, ATLAS
# SN 2018bgq                             ZTF                     ZTF
# SN 2018bas                 ZTF, Pan-STARRS         ZTF, Pan-STARRS
#
#            Classifying Group/s      Associated Group/s  ... Public  \
# Name                                                    ...
# SN 2020zct              REFITT             REFITT; ZTF  ...      1
# SN 2020uma                 ZTF         Pan-STARRS; ZTF  ...      1
# SN 2020ule                 ZTF              ATLAS; ZTF  ...      1
# SN 2020ugv                 ZTF                     ZTF  ...      1
# SN 2020uea                 ZTF  ATLAS; Pan-STARRS; ZTF  ...      1
# ...                        ...                     ...  ...    ...
# SN 2018bxr                 ZTF              ATLAS; ZTF  ...      1
# SN 2018bsu                 ZTF                     ZTF  ...      1
# SN 2018bij                 ZTF              ATLAS; ZTF  ...      1
# SN 2018bgq                 ZTF                     ZTF  ...      1
# SN 2018bas                 ZTF         Pan-STARRS; ZTF  ...      1
#
#            End Prop. Period Discovery Mag/Flux  Discovery Filter  \
# Name
# SN 2020zct              NaN            19.8499             g-PTF
# SN 2020uma              NaN            19.8400             g-ZTF
# SN 2020ule              NaN            19.9200             g-ZTF
# SN 2020ugv              NaN            20.0451             g-ZTF
# SN 2020uea              NaN            19.1293             r-ZTF
# ...                     ...                ...               ...
# SN 2018bxr              NaN            20.0900             r-ZTF
# SN 2018bsu              NaN            19.5300             r-ZTF
# SN 2018bij              NaN            18.6900             r-ZTF
# SN 2018bgq              NaN            18.9100             r-ZTF
# SN 2018bas              NaN            19.6000             r-ZTF
#
#                 Discovery Date (UT)              Sender  Remarks  \
# Name
# SN 2020zct  2020-09-26 11:35:27.744          REFITT_BOT      NaN
# SN 2020uma  2020-09-23 06:14:24.000            ZTF_Bot1      NaN
# SN 2020ule  2020-09-27 08:07:24.672  ZTF_AMPEL_COMPLETE      NaN
# SN 2020ugv  2020-09-24 07:25:17.999              ALeRCE      NaN
# SN 2020uea  2020-09-24 09:37:11.004              ALeRCE      NaN
# ...                             ...                 ...      ...
# SN 2018bxr  2018-05-19 06:28:48.000            ZTF_Bot1      NaN
# SN 2018bsu  2018-05-14 09:20:09.000            ZTF_Bot1      NaN
# SN 2018bij  2018-05-07 03:41:45.000            ZTF_Bot1      NaN
# SN 2018bgq  2018-05-04 06:37:26.000            ZTF_Bot1      NaN
# SN 2018bas  2018-04-08 06:57:36.000            ZTF_Bot1      NaN
#
#               Discovery Bibcode Classification Bibcodes Ext. catalog/s
# Name
# SN 2020zct  2020TNSTR3408....1W     2020TNSCR3413....1W            NaN
# SN 2020uma  2020TNSTR2971....1D     2020TNSCR2973....1D            NaN
# SN 2020ule  2020TNSTR2972....1N     2020TNSCR3192....1D            NaN
# SN 2020ugv  2020TNSTR2941....1F     2020TNSCR3289....1D            NaN
# SN 2020uea  2020TNSTR2928....1F     2020TNSCR2973....1D            NaN
# ...                         ...                     ...            ...
# SN 2018bxr  2018TNSTR.705....1F     2018TNSCR1071....1F            NaN
# SN 2018bsu  2018TNSTR.658....1F     2019TNSCR.933....1F            NaN
# SN 2018bij  2018TNSTR.610....1F     2018TNSCR1071....1F            NaN
# SN 2018bgq  2018TNSTR.602....1F     2019TNSCR.892....1F            NaN
# SN 2018bas  2018TNSTR.539....1L     2018TNSCR.540....1L            NaN
#
# [2127 rows x 24 columns]

# %%
Counter(keep_tns_result_df["Obj. Type"])
# Out:
# Counter({'SN Iax[02cx-like]': 7,
#          'SN Ia': 1534,
#          'SN Ic': 41,
#          'SN IIb': 28,
#          'SN Ib': 34,
#          'SN II': 250,
#          'SN Ia-91T-like': 46,
#          'SN Ic-BL': 20,
#          'SN Ib/c': 8,
#          'SN Ia-pec': 12,
#          'SN IIn': 45,
#          'SLSN-I': 25,
#          'SN Ia-91bg-like': 8,
#          'SN IIP': 24,
#          'TDE': 9,
#          'SN Ibn': 11,
#          'SLSN-II': 15,
#          'SN': 2,
#          'SN Ia-CSM': 2,
#          'SN Ia-Ca-rich': 1,
#          'SN Icn': 1,
#          'SN II-pec': 1,
#          'ILRT': 1,
#          'SN Ib-Ca-rich': 2})

# %%
np.unique(keep_tns_result_df["Obj. Type"])
# Out:
# array(['ILRT', 'SLSN-I', 'SLSN-II', 'SN', 'SN II', 'SN II-pec', 'SN IIP',
#        'SN IIb', 'SN IIn', 'SN Ia', 'SN Ia-91T-like', 'SN Ia-91bg-like',
#        'SN Ia-CSM', 'SN Ia-Ca-rich', 'SN Ia-pec', 'SN Iax[02cx-like]',
#        'SN Ib', 'SN Ib-Ca-rich', 'SN Ib/c', 'SN Ibn', 'SN Ic', 'SN Ic-BL',
#        'SN Icn', 'TDE'], dtype=object)

# %% [markdown]
# ## Extract lc features as function of time for {objid}-timeseries.csv

# %%
import requests
from requests.auth import HTTPBasicAuth
import astropy.table as at
import matplotlib
from matplotlib.transforms import Bbox
from matplotlib.backends.backend_pdf import PdfPages
from astropy.io import fits
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy.coordinates import Angle
import astropy.units as u
from astropy.visualization import PercentileInterval, AsinhStretch
from astroquery.mast import Catalogs
from astroquery.sdss import SDSS
from astroquery.simbad import Simbad

import light_curve as lc
from itertools import chain
import light_curve as lc
from astropy.table import MaskedColumn

from PIL import Image
import os
import sys
import shutil
import glob
import json

import math

import warnings
warnings.filterwarnings("ignore")

import time
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

import os
import sys
import annoy
from annoy import AnnoyIndex
import random



from IPython.display import display_markdown

from collections import Counter

from sklearn import preprocessing
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial import cKDTree
from sklearn.decomposition import PCA
from sklearn.decomposition import SparsePCA

from alerce.core import Alerce
alerce = Alerce()

import antares_client

df_path = "/Users/patrickaleo/Desktop/Illinois/LAISS-antares/repo/tables/before_lc-feature-extractor_tns_search/timeseries"

plt.style.use('fig_publication.mplstyle')
# %config InlineBackend.figure_format = 'retina'  #for MacOS, make plots crisp

# %%
def replace_magn_with_flux(s):
    if 'magnitude' in s:
        return s.replace('magnitudes', 'fluxes').replace('magnitude', 'flux')
    return f'{s} for flux light curve'

def create_base_features_class(
        magn_extractor,
        flux_extractor,
        bands=('R', 'g',),
    ):
    feature_names = ([f'{name}_magn' for name in magn_extractor.names]
                     + [f'{name}_flux' for name in flux_extractor.names])
    
    property_names = {band: [f'feature_{name}_{band}'.lower()
                             for name in feature_names]
                      for band in bands}
    
    features_count = len(feature_names)
    
    return feature_names, property_names, features_count


MAGN_EXTRACTOR = lc.Extractor(
    lc.Amplitude(),
    lc.AndersonDarlingNormal(),
    lc.BeyondNStd(1.0),
    lc.BeyondNStd(2.0),
    lc.Cusum(),
    lc.EtaE(),
    lc.InterPercentileRange(0.02),
    lc.InterPercentileRange(0.1),
    lc.InterPercentileRange(0.25),
    lc.Kurtosis(),
    lc.LinearFit(),
    lc.LinearTrend(),
    lc.MagnitudePercentageRatio(0.4, 0.05),
    lc.MagnitudePercentageRatio(0.2, 0.05),
    lc.MaximumSlope(),
    lc.Mean(),
    lc.MedianAbsoluteDeviation(),
    lc.PercentAmplitude(),
    lc.PercentDifferenceMagnitudePercentile(0.05),
    lc.PercentDifferenceMagnitudePercentile(0.1),
    lc.MedianBufferRangePercentage(0.1),
    lc.MedianBufferRangePercentage(0.2),
    lc.Periodogram(
        peaks=5,
        resolution=10.0,
        max_freq_factor=2.0,
        nyquist='average',
        fast=True,
        features=(
            lc.Amplitude(),
            lc.BeyondNStd(2.0),
            lc.BeyondNStd(3.0),
            lc.StandardDeviation(),
        ),
    ),
    lc.ReducedChi2(),
    lc.Skew(),
    lc.StandardDeviation(),
    lc.StetsonK(),
    lc.WeightedMean(),
)

FLUX_EXTRACTOR = lc.Extractor(
    lc.AndersonDarlingNormal(),
    lc.Cusum(),
    lc.EtaE(),
    lc.ExcessVariance(),
    lc.Kurtosis(),
    lc.MeanVariance(),
    lc.ReducedChi2(),
    lc.Skew(),
    lc.StetsonK(),
)

def remove_simultaneous_alerts(table):
    """Remove alert duplicates"""
    dt = np.diff(table['ant_mjd'], append=np.inf)
    return table[dt != 0]
    
def get_detections(photometry, band):
    """Extract clean light curve in given band from locus photometry"""
    band_lc = photometry[(photometry['ant_passband'] == band) & (~photometry['ant_mag'].isna())]
    idx = ~MaskedColumn(band_lc['ant_mag']).mask
    detections = remove_simultaneous_alerts(band_lc[idx])
    return detections

# %%
import astro_ghost
# from astro_ghost.PS1QueryFunctions import getAllPostageStamps
# from astro_ghost.TNSQueryFunctions import getTNSSpectra
# from astro_ghost.NEDQueryFunctions import getNEDSpectra
from astro_ghost.ghostHelperFunctions import getTransientHosts, getGHOST
from astropy.coordinates import SkyCoord
from astropy import units as u
from datetime import datetime
import tempfile

# Throw RA/DEC into ghost with just DLR method, gentle starcut
# Sets environ var to find ghost.csv
os.environ['GHOST_PATH'] = './host_info'
# Then don't use getGHOST(real=True, verbose=verbose)
getGHOST(real=True,verbose=False)
# Out:
# GHOST database already exists in the install path!

# %%
astro_ghost.__version__
# Out:
# '2.0.16'

# %%
def extract_lc_and_host_features(ztf_id_ref, spec_class, show_lc=False, show_host=False):
    ztf_id_ref = ztf_id_ref #'ZTF20aalxlis' #'ZTF21abmspzt'
    spec_class = spec_class
    df_path = "/Users/patrickaleo/Desktop/Illinois/LAISS-antares/repo/tables/before_lc-feature-extractor_tns_search/timeseries"

    try:
        ref_info = antares_client.search.get_by_ztf_object_id(ztf_object_id=ztf_id_ref)
        df_ref = ref_info.timeseries.to_pandas()
    except:
        print("antares_client can't find this object. Skip! Continue...")
        return
    
    df_ref_g = df_ref[(df_ref.ant_passband == 'g') & (~df_ref.ant_mag.isna())]
    df_ref_r = df_ref[(df_ref.ant_passband == 'R') & (~df_ref.ant_mag.isna())]

    try:
        mjd_idx_at_min_mag_r_ref = df_ref_r[['ant_mag']].reset_index().idxmin().ant_mag
        mjd_idx_at_min_mag_g_ref = df_ref_g[['ant_mag']].reset_index().idxmin().ant_mag
    except:
        print(f"No obs for {ztf_id_ref}. pass!\n")
        return
    
    if show_lc:
        fig, ax = plt.subplots(figsize=(7,7))
        plt.gca().invert_yaxis()

        ax.errorbar(x=df_ref_r.ant_mjd, y=df_ref_r.ant_mag, yerr=df_ref_r.ant_magerr, fmt='o', c='r', 
                    label=f'REF: {ztf_id_ref}')
        ax.errorbar(x=df_ref_g.ant_mjd, y=df_ref_g.ant_mag, yerr=df_ref_g.ant_magerr, fmt='o', c='g')
        plt.show()
        
    min_obs_count=4

    lightcurve = ref_info.lightcurve
    feature_names, property_names, features_count = create_base_features_class(MAGN_EXTRACTOR, FLUX_EXTRACTOR)


    g_obs = list(get_detections(lightcurve, 'g').ant_mjd.values)
    r_obs = list(get_detections(lightcurve, 'R').ant_mjd.values)
    mjd_l = sorted(g_obs+r_obs)

    lc_properties_d_l = []
    len_det_counter_r,len_det_counter_g = 0,0

    band_lc = lightcurve[(~lightcurve['ant_mag'].isna())]
    idx = ~MaskedColumn(band_lc['ant_mag']).mask
    all_detections = remove_simultaneous_alerts(band_lc[idx])
    for ob, mjd in enumerate(mjd_l): # requires 4 obs
        # do time evolution of detections - in chunks

        detections_pb = all_detections[all_detections['ant_mjd'].values <= mjd]
        #print(detections)
        lc_properties_d={}
        for band, names in property_names.items():
            detections = detections_pb[detections_pb['ant_passband'] == band]

            # Ensure locus has >3 obs for calculation
            if (len(detections) < min_obs_count):
                continue
            #print(detections)

            t = detections['ant_mjd'].values
            m = detections['ant_mag'].values
            merr = detections['ant_magerr'].values
            flux = np.power(10.0, -0.4 * m)
            fluxerr = 0.5 * flux * (np.power(10.0, 0.4 * merr) - np.power(10.0, -0.4 * merr))

            magn_features = MAGN_EXTRACTOR(
                t,
                m,
                merr,
                fill_value=None,
            )
            flux_features = FLUX_EXTRACTOR(
                t,
                flux,
                fluxerr,
                fill_value=None,
            )

            # After successfully calculating features, set locus properties and tag
            lc_properties_d["obs_num"] = int(ob)
            lc_properties_d["mjd_cutoff"] = mjd
            lc_properties_d["ztf_object_id"] = ztf_id_ref
            #print(band, m)
            for name, value in zip(names, chain(magn_features, flux_features)):
                lc_properties_d[name] = value
                #if name == "feature_amplitude_magn_g": print(m, value, band)
            #print("%%%%%%%%")
        lc_properties_d_l.append(lc_properties_d)

    lc_properties_d_l = [d for d in lc_properties_d_l if d]
    lc_properties_df = pd.DataFrame(lc_properties_d_l)
    if len(lc_properties_df) == 0: 
        print(f"Not enough obs for {ztf_id_ref}. pass!\n")
        return
    print(f"Extracted LC features for {ztf_id_ref}!")
    
    # Get GHOST features
    ra,dec=np.mean(df_ref.ant_ra),np.mean(df_ref.ant_dec)
    snName=[ztf_id_ref, ztf_id_ref]
    snCoord = [SkyCoord(ra*u.deg, dec*u.deg, frame='icrs'), SkyCoord(ra*u.deg, dec*u.deg, frame='icrs')]
    with tempfile.TemporaryDirectory() as tmp:
        try:
            hosts = getTransientHosts(transientName=snName, snCoord=snCoord, GLADE=True, verbose=0, 
                                  starcut='gentle', ascentMatch=False, savepath=tmp, redo_search=False)
        except:
            print(f"GHOST error for {ztf_id_ref}. Retry without GLADE. \n")
            hosts = getTransientHosts(transientName=snName, snCoord=snCoord, GLADE=False, verbose=0, 
                                  starcut='gentle', ascentMatch=False, savepath=tmp, redo_search=False)       
            
    if len(hosts) > 1:
        hosts = pd.DataFrame(hosts.loc[0]).T
    
    hosts_df = hosts[feature_names_hostgal]
    hosts_df = hosts_df[~hosts_df.isnull().any(axis=1)]

    if len(hosts_df) < 1:
        # if any features are nan, we can't use as input
        print(f"Some features are NaN for {ztf_id_ref}. Skip!\n")
        return
        
    if show_host:
        print(f'http://ps1images.stsci.edu/cgi-bin/ps1cutouts?pos={hosts.raMean.values[0]}+{hosts.decMean.values[0]}&filter=color')
    
    # Define the label array
    label_arr = np.array(['ILRT', 'SLSN-I', 'SLSN-II', 'SN', 'SN II', 'SN II-pec', 'SN IIP',
       'SN IIb', 'SN IIn', 'SN Ia', 'SN Ia-91T-like', 'SN Ia-91bg-like',
       'SN Ia-CSM', 'SN Ia-Ca-rich', 'SN Ia-pec', 'SN Iax[02cx-like]',
       'SN Ib', 'SN Ib-Ca-rich', 'SN Ib/c', 'SN Ibn', 'SN Ic', 'SN Ic-BL',
       'SN Icn', 'TDE'])

    # Define the spectroscopic class
    spec_class = spec_class

    # Find the index of the spectroscopic class in the label array
    class_index = np.where(label_arr == spec_class)[0]

    # Create a one-hot encoded array with all zeros
    onehot_array = np.zeros(len(label_arr), dtype=float)

    # Set the corresponding index to 1
    onehot_array[class_index] = 1

    # Reshape the array to have a shape of (1, num_classes)
    onehot_array = onehot_array.reshape(1, -1)
    
    onehot_df = pd.DataFrame(np.array(onehot_array, dtype=float), columns=label_arr)
    onehot_df = pd.concat([onehot_df] * len(lc_properties_df), ignore_index=True)
    
    hosts_df = hosts[feature_names_hostgal]
    hosts_df = pd.concat([hosts_df] * len(lc_properties_df), ignore_index=True)

    lc_and_hosts_df = pd.concat([lc_properties_df, hosts_df, onehot_df], axis=1)
    lc_and_hosts_df = lc_and_hosts_df.set_index('ztf_object_id')
    lc_and_hosts_df.to_csv(f'{df_path}/{lc_and_hosts_df.index[0]}_timeseries.csv')
    
    print(f"Saved results for {ztf_id_ref}!\n")

# %%
# %%time
for i, (ztf_obj_test, spec_cls) in enumerate(zip(keep_tns_result_df["Disc. Internal Name"][1166:], 
                        keep_tns_result_df["Obj. Type"][1166:])):
    
    if i % 50 == 0: print(i)
    
    if os.path.exists(f"/Users/patrickaleo/Desktop/Illinois/LAISS-antares/repo/tables/before_lc-feature-extractor_tns_search/timeseries/{ztf_obj_test}_timeseries.csv"): 
        print(f'{ztf_obj_test} is already made. Continue!\n')
        continue
    
    else:
        extract_lc_and_host_features(ztf_id_ref=ztf_obj_test, spec_class=spec_cls)
# Out:
# 0
# Extracted LC features for ZTF19abzsitm!
# Saved results for ZTF19abzsitm!
#
# Extracted LC features for ZTF19abzhfjj!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19abzhfjj!
#
# Extracted LC features for ZTF19abzrhgq!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abzrhgq!
#
# Extracted LC features for ZTF19abzrdup!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abzrdup. Skip!
#
# Extracted LC features for ZTF19abzqkdz!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abzqkdz!
#
# Extracted LC features for ZTF19abzlsbl!
# Saved results for ZTF19abzlsbl!
#
# Extracted LC features for ZTF19abyhxzp!
# Saved results for ZTF19abyhxzp!
#
# Extracted LC features for ZTF19abzmnuk!
# Saved results for ZTF19abzmnuk!
#
# Extracted LC features for ZTF19abzlmwn!
# Saved results for ZTF19abzlmwn!
#
# Extracted LC features for ZTF19abzkyjy!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19abzkyjy!
#
# Extracted LC features for ZTF19abzkexb!
# Saved results for ZTF19abzkexb!
#
# Extracted LC features for ZTF19abzhzet!
# Saved results for ZTF19abzhzet!
#
# Extracted LC features for ZTF19abzhvxk!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abzhvxk!
#
# Extracted LC features for ZTF19abpmetl!
# Saved results for ZTF19abpmetl!
#
# Extracted LC features for ZTF19abzgdfu!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19abzgdfu!
#
# Extracted LC features for ZTF19abzfmak!
# Saved results for ZTF19abzfmak!
#
# Extracted LC features for ZTF19abyigib!
# Saved results for ZTF19abyigib!
#
# Extracted LC features for ZTF19abxfeln!
# Some features are NaN for ZTF19abxfeln. Skip!
#
# Extracted LC features for ZTF19abxekxi!
# Saved results for ZTF19abxekxi!
#
# Extracted LC features for ZTF19abyzuos!
# Saved results for ZTF19abyzuos!
#
# Extracted LC features for ZTF19abyjjxp!
# Saved results for ZTF19abyjjxp!
#
# Extracted LC features for ZTF19abyuzch!
# Saved results for ZTF19abyuzch!
#
# Extracted LC features for ZTF19abyjhpz!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19abyjhpz!
#
# Extracted LC features for ZTF19abwamby!
# Saved results for ZTF19abwamby!
#
# Extracted LC features for ZTF19abxtdgh!
# Saved results for ZTF19abxtdgh!
#
# Extracted LC features for ZTF19abxiqve!
# Saved results for ZTF19abxiqve!
#
# Extracted LC features for ZTF19abymhad!
# Saved results for ZTF19abymhad!
#
# Extracted LC features for ZTF19abyfbik!
# Saved results for ZTF19abyfbik!
#
# Extracted LC features for ZTF19abyjgal!
# Saved results for ZTF19abyjgal!
#
# Extracted LC features for ZTF19abwsxug!
# Saved results for ZTF19abwsxug!
#
# Extracted LC features for ZTF19abyikbv!
# Saved results for ZTF19abyikbv!
#
# Extracted LC features for ZTF19abycslo!
# Some features are NaN for ZTF19abycslo. Skip!
#
# Extracted LC features for ZTF19abwsdic!
# Saved results for ZTF19abwsdic!
#
# Extracted LC features for ZTF19abxgmzr!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19abxgmzr. Skip!
#
# Extracted LC features for ZTF19abxfunp!
# Saved results for ZTF19abxfunp!
#
# No obs for ZTF19abxwhxm. pass!
#
# Extracted LC features for ZTF19abxfhrq!
# Saved results for ZTF19abxfhrq!
#
# Extracted LC features for ZTF19abxdnzt!
# Saved results for ZTF19abxdnzt!
#
# Extracted LC features for ZTF19abxdnhr!
# Saved results for ZTF19abxdnhr!
#
# Extracted LC features for ZTF19abxqppy!
# Some features are NaN for ZTF19abxqppy. Skip!
#
# Extracted LC features for ZTF19abvvpoh!
# Saved results for ZTF19abvvpoh!
#
# Extracted LC features for ZTF19abxvtxk!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abxvtxk!
#
# Extracted LC features for ZTF19abxvtmy!
# Saved results for ZTF19abxvtmy!
#
# Extracted LC features for ZTF19abxvtmn!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abxvtmn!
#
# Extracted LC features for ZTF19abxvtiy!
# Saved results for ZTF19abxvtiy!
#
# Extracted LC features for ZTF19abxvles!
# Saved results for ZTF19abxvles!
#
# Extracted LC features for ZTF19abxvjzn!
# Saved results for ZTF19abxvjzn!
#
# Extracted LC features for ZTF19abxvjkn!
# Saved results for ZTF19abxvjkn!
#
# Extracted LC features for ZTF19abxtcio!
# Saved results for ZTF19abxtcio!
#
# Extracted LC features for ZTF19abwscog!
# Saved results for ZTF19abwscog!
#
# 50
# Extracted LC features for ZTF19abwouqp!
# Some features are NaN for ZTF19abwouqp. Skip!
#
# Extracted LC features for ZTF19abwnpus!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19abwnpus. Skip!
#
# Extracted LC features for ZTF19abvjcii!
# Saved results for ZTF19abvjcii!
#
# Extracted LC features for ZTF19abwaohs!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19abwaohs. Skip!
#
# Extracted LC features for ZTF19abwsagv!
# Saved results for ZTF19abwsagv!
#
# Extracted LC features for ZTF19abxnycf!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abxnycf. Skip!
#
# Extracted LC features for ZTF19abxihut!
# Saved results for ZTF19abxihut!
#
# Extracted LC features for ZTF19abxigfc!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abxigfc!
#
# Extracted LC features for ZTF19abuzpmr!
# Saved results for ZTF19abuzpmr!
#
# Extracted LC features for ZTF19abwsecm!
# Saved results for ZTF19abwsecm!
#
# Extracted LC features for ZTF19abxjrge!
# Saved results for ZTF19abxjrge!
#
# Extracted LC features for ZTF19abvgwvp!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abvgwvp!
#
# Extracted LC features for ZTF19abrvagn!
# Saved results for ZTF19abrvagn!
#
# Extracted LC features for ZTF19abvhkst!
# Saved results for ZTF19abvhkst!
#
# Extracted LC features for ZTF19abuzinv!
# Some features are NaN for ZTF19abuzinv. Skip!
#
# Extracted LC features for ZTF18abqlykl!
# Saved results for ZTF18abqlykl!
#
# Extracted LC features for ZTF19abvgnxg!
# Saved results for ZTF19abvgnxg!
#
# Extracted LC features for ZTF19abuxhqc!
# Saved results for ZTF19abuxhqc!
#
# Extracted LC features for ZTF19abvjdfc!
# Saved results for ZTF19abvjdfc!
#
# Extracted LC features for ZTF19abubagk!
# Saved results for ZTF19abubagk!
#
# Extracted LC features for ZTF19abuazly!
# Saved results for ZTF19abuazly!
#
# Extracted LC features for ZTF19abrcvzz!
# Saved results for ZTF19abrcvzz!
#
# Extracted LC features for ZTF19abulzlj!
# Saved results for ZTF19abulzlj!
#
# Extracted LC features for ZTF19abvhduf!
# Saved results for ZTF19abvhduf!
#
# Extracted LC features for ZTF19abukbit!
# Saved results for ZTF19abukbit!
#
# Extracted LC features for ZTF19abtulak!
# Saved results for ZTF19abtulak!
#
# Extracted LC features for ZTF19abrilok!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abrilok. Skip!
#
# Extracted LC features for ZTF19abuclhk!
# Saved results for ZTF19abuclhk!
#
# Extracted LC features for ZTF19abvanim!
# Saved results for ZTF19abvanim!
#
# Extracted LC features for ZTF19abvalfd!
# Saved results for ZTF19abvalfd!
#
# Extracted LC features for ZTF19abvdbyx!
# Saved results for ZTF19abvdbyx!
#
# Extracted LC features for ZTF19abvdgqo!
# Saved results for ZTF19abvdgqo!
#
# Extracted LC features for ZTF19abucvgu!
# Saved results for ZTF19abucvgu!
#
# Extracted LC features for ZTF19abqyoxj!
# Saved results for ZTF19abqyoxj!
#
# Extracted LC features for ZTF19abqyouo!
# Some features are NaN for ZTF19abqyouo. Skip!
#
# Extracted LC features for ZTF19abrcpnj!
# Saved results for ZTF19abrcpnj!
#
# Extracted LC features for ZTF19abqsvue!
# Saved results for ZTF19abqsvue!
#
# Not enough obs for ZTF19abtuflm. pass!
# Extracted LC features for ZTF19abrirdm!
# Saved results for ZTF19abrirdm!
#
# Extracted LC features for ZTF19abtnftd!
# Saved results for ZTF19abtnftd!
#
# Extracted LC features for ZTF19abuonnx!
# Saved results for ZTF19abuonnx!
#
# Extracted LC features for ZTF19abqyoxt!
# Saved results for ZTF19abqyoxt!
#
# Extracted LC features for ZTF19abrmlxu!
# Saved results for ZTF19abrmlxu!
#
# Extracted LC features for ZTF19abueupg!
# Saved results for ZTF19abueupg!
#
# Extracted LC features for ZTF19abukakm!
# Saved results for ZTF19abukakm!
#
# Extracted LC features for ZTF19abudlps!
# Saved results for ZTF19abudlps!
#
# Extracted LC features for ZTF19abudjie!
# Some features are NaN for ZTF19abudjie. Skip!
#
# Extracted LC features for ZTF19absfopz!
# Saved results for ZTF19absfopz!
#
# Not enough obs for ZTF19abtuigb. pass!
#
# Extracted LC features for ZTF19abttstb!
# Saved results for ZTF19abttstb!
#
# 100
# Extracted LC features for ZTF19abtsnyy!
# Saved results for ZTF19abtsnyy!
#
# Extracted LC features for ZTF19abtslqm!
# Saved results for ZTF19abtslqm!
#
# Not enough obs for ZTF19abttrte. pass!
#
# Extracted LC features for ZTF19abkfshj!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abkfshj. Skip!
#
# Extracted LC features for ZTF19abqsmns!
# Some features are NaN for ZTF19abqsmns. Skip!
#
# Extracted LC features for ZTF19abrsuah!
# Some features are NaN for ZTF19abrsuah. Skip!
#
# Extracted LC features for ZTF19abnagzk!
# Saved results for ZTF19abnagzk!
#
# Extracted LC features for ZTF19abozuxh!
# Saved results for ZTF19abozuxh!
#
# Extracted LC features for ZTF19abrbmvt!
# Saved results for ZTF19abrbmvt!
#
# Extracted LC features for ZTF19abrtjsf!
# Saved results for ZTF19abrtjsf!
#
# Extracted LC features for ZTF19abrsssx!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abrsssx. Skip!
#
# Extracted LC features for ZTF19abqjypm!
# Saved results for ZTF19abqjypm!
#
# Extracted LC features for ZTF19abqmurd!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19abqmurd!
#
# Extracted LC features for ZTF19abpxcaf!
# Saved results for ZTF19abpxcaf!
#
# Extracted LC features for ZTF19abqsojs!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abqsojs. Skip!
#
# Extracted LC features for ZTF19abotfag!
# Saved results for ZTF19abotfag!
#
# Extracted LC features for ZTF19abqgzea!
# Some features are NaN for ZTF19abqgzea. Skip!
#
# Extracted LC features for ZTF19abqysic!
# Some features are NaN for ZTF19abqysic. Skip!
#
# Extracted LC features for ZTF19abrlvij!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abrlvij!
#
# Extracted LC features for ZTF19abqmpsr!
# Saved results for ZTF19abqmpsr!
#
# Extracted LC features for ZTF19abrogbl!
# Saved results for ZTF19abrogbl!
#
# Extracted LC features for ZTF19abqxibq!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abqxibq!
#
# Extracted LC features for ZTF19abpypvc!
# Saved results for ZTF19abpypvc!
#
# Extracted LC features for ZTF19abpxttd!
# Saved results for ZTF19abpxttd!
#
# Extracted LC features for ZTF19abrirmk!
# Saved results for ZTF19abrirmk!
#
# Extracted LC features for ZTF19abqqrib!
# Saved results for ZTF19abqqrib!
#
# Extracted LC features for ZTF19abpzuzd!
# Saved results for ZTF19abpzuzd!
#
# Extracted LC features for ZTF19abqqmui!
# Saved results for ZTF19abqqmui!
#
# Not enough obs for ZTF19abrdxbh. pass!
#
# Extracted LC features for ZTF19abqmsnk!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abqmsnk. Skip!
#
# No obs for ZTF19abqrxhy. pass!
#
# Extracted LC features for ZTF19abpztlw!
# Saved results for ZTF19abpztlw!
#
# Extracted LC features for ZTF19abqwtfu!
# Saved results for ZTF19abqwtfu!
#
# Extracted LC features for ZTF19abqwsuf!
# Saved results for ZTF19abqwsuf!
#
# Extracted LC features for ZTF19abqgrht!
# Saved results for ZTF19abqgrht!
#
# Extracted LC features for ZTF19abqsvgf!
# Saved results for ZTF19abqsvgf!
#
# Extracted LC features for ZTF19abqrhvy!
# Some features are NaN for ZTF19abqrhvy. Skip!
#
# Extracted LC features for ZTF19abqkpoi!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abqkpoi. Skip!
#
# Extracted LC features for ZTF19abqimia!
# Saved results for ZTF19abqimia!
#
# Extracted LC features for ZTF19abqrrto!
# Saved results for ZTF19abqrrto!
#
# Extracted LC features for ZTF19abqxhhr!
# Saved results for ZTF19abqxhhr!
#
# Extracted LC features for ZTF19abqviuy!
# Saved results for ZTF19abqviuy!
#
# Extracted LC features for ZTF19abqykei!
# Saved results for ZTF19abqykei!
#
# Extracted LC features for ZTF19abqgytb!
# Saved results for ZTF19abqgytb!
#
# Extracted LC features for ZTF19abqgtqo!
# Saved results for ZTF19abqgtqo!
#
# Extracted LC features for ZTF19abqrhvt!
# Saved results for ZTF19abqrhvt!
#
# Not enough obs for ZTF19abqmucc. pass!
#
# Extracted LC features for ZTF19abqmpti!
# Saved results for ZTF19abqmpti!
#
# Extracted LC features for ZTF19abqqrgy!
# Saved results for ZTF19abqqrgy!
#
# Extracted LC features for ZTF19abpxiff!
# Some features are NaN for ZTF19abpxiff. Skip!
#
# 150
# Extracted LC features for ZTF19abqmjdq!
# Saved results for ZTF19abqmjdq!
#
# Extracted LC features for ZTF19abpyjqx!
# Saved results for ZTF19abpyjqx!
#
# Extracted LC features for ZTF19aboxjlj!
# Saved results for ZTF19aboxjlj!
#
# Extracted LC features for ZTF19aboudfp!
# Saved results for ZTF19aboudfp!
#
# Extracted LC features for ZTF19abqlrtb!
# Saved results for ZTF19abqlrtb!
#
# Extracted LC features for ZTF19abqirpa!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abqirpa. Skip!
#
# Extracted LC features for ZTF19abqhobb!
# Saved results for ZTF19abqhobb!
#
# No obs for ZTF19abpuikr. pass!
#
# No obs for ZTF19abqbzal. pass!
#
# Extracted LC features for ZTF19abqanpy!
# Saved results for ZTF19abqanpy!
#
# Extracted LC features for ZTF19ablrkfz!
# Saved results for ZTF19ablrkfz!
#
# Extracted LC features for ZTF19abpfxfs!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19abpfxfs!
#
# Extracted LC features for ZTF19aboqpry!
# Saved results for ZTF19aboqpry!
#
# Extracted LC features for ZTF19abnmnrz!
# Some features are NaN for ZTF19abnmnrz. Skip!
#
# Not enough obs for ZTF19abpqvdh. pass!
#
# Extracted LC features for ZTF19ablpasc!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19ablpasc!
#
# Extracted LC features for ZTF19abpelgt!
# Saved results for ZTF19abpelgt!
#
# Extracted LC features for ZTF19abpgggu!
# Saved results for ZTF19abpgggu!
#
# Extracted LC features for ZTF19abpbmli!
# Saved results for ZTF19abpbmli!
#
# Extracted LC features for ZTF19abovstj!
# Saved results for ZTF19abovstj!
#
# Extracted LC features for ZTF19ablusdf!
# Some features are NaN for ZTF19ablusdf. Skip!
#
# Extracted LC features for ZTF19ablfcjr!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19ablfcjr!
#
# Extracted LC features for ZTF19abpidqn!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abpidqn. Skip!
#
# Extracted LC features for ZTF19ablpxtf!
# Saved results for ZTF19ablpxtf!
#
# Extracted LC features for ZTF19abplfxs!
# Some features are NaN for ZTF19abplfxs. Skip!
#
# Extracted LC features for ZTF19abornyn!
# Saved results for ZTF19abornyn!
#
# Extracted LC features for ZTF19abpbbxx!
# Saved results for ZTF19abpbbxx!
#
# Extracted LC features for ZTF19abopyyu!
# Saved results for ZTF19abopyyu!
#
# Extracted LC features for ZTF19abopflp!
# Saved results for ZTF19abopflp!
#
# Extracted LC features for ZTF19abpbqor!
# Saved results for ZTF19abpbqor!
#
# Extracted LC features for ZTF19abpbopt!
# Saved results for ZTF19abpbopt!
#
# Extracted LC features for ZTF19abpangr!
# Saved results for ZTF19abpangr!
#
# Extracted LC features for ZTF19abocled!
# Some features are NaN for ZTF19abocled. Skip!
#
# Extracted LC features for ZTF19abowcic!
# Saved results for ZTF19abowcic!
#
# Extracted LC features for ZTF19abobxik!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abobxik!
#
# Extracted LC features for ZTF19abnkrcd!
# Saved results for ZTF19abnkrcd!
#
# Extracted LC features for ZTF19abnimpq!
# Saved results for ZTF19abnimpq!
#
# Extracted LC features for ZTF19abomiel!
# Saved results for ZTF19abomiel!
#
# Extracted LC features for ZTF19abmzmom!
# Saved results for ZTF19abmzmom!
#
# Extracted LC features for ZTF19abmqasg!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19abmqasg. Skip!
#
# Extracted LC features for ZTF19abmylxw!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abmylxw. Skip!
#
# Extracted LC features for ZTF19abmpoxa!
# Saved results for ZTF19abmpoxa!
#
# Extracted LC features for ZTF19ablpnmk!
# Some features are NaN for ZTF19ablpnmk. Skip!
#
# Extracted LC features for ZTF19abmolyr!
# Some features are NaN for ZTF19abmolyr. Skip!
#
# Extracted LC features for ZTF19abnktws!
# Saved results for ZTF19abnktws!
#
# Extracted LC features for ZTF19abmtpvz!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19abmtpvz. Skip!
#
# Extracted LC features for ZTF19abkdeae!
# Saved results for ZTF19abkdeae!
#
# Extracted LC features for ZTF19abkcpxe!
# Saved results for ZTF19abkcpxe!
#
# Extracted LC features for ZTF18abugthp!
# Saved results for ZTF18abugthp!
#
# Extracted LC features for ZTF19abjsmmv!
# Saved results for ZTF19abjsmmv!
#
# 200
# Extracted LC features for ZTF19abhibzk!
# Saved results for ZTF19abhibzk!
#
# Extracted LC features for ZTF19ablfaey!
# Saved results for ZTF19ablfaey!
#
# Extracted LC features for ZTF19ablojrw!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19ablojrw. Skip!
#
# Extracted LC features for ZTF19abimzvh!
# Saved results for ZTF19abimzvh!
#
# Extracted LC features for ZTF19abjozed!
# Saved results for ZTF19abjozed!
#
# Extracted LC features for ZTF19abjrjdw!
# Some features are NaN for ZTF19abjrjdw. Skip!
#
# Extracted LC features for ZTF19ablqnuw!
# Some features are NaN for ZTF19ablqnuw. Skip!
#
# Extracted LC features for ZTF19abjswdz!
# Saved results for ZTF19abjswdz!
#
# Extracted LC features for ZTF19ablpfhz!
# Saved results for ZTF19ablpfhz!
#
# Extracted LC features for ZTF19ablovot!
# Saved results for ZTF19ablovot!
#
# Extracted LC features for ZTF19abkdrir!
# Saved results for ZTF19abkdrir!
#
# Extracted LC features for ZTF19abjpntj!
# Saved results for ZTF19abjpntj!
#
# Extracted LC features for ZTF19abiztut!
# Saved results for ZTF19abiztut!
#
# Extracted LC features for ZTF19abjarhj!
# Saved results for ZTF19abjarhj!
#
# Extracted LC features for ZTF19abinjcy!
# Saved results for ZTF19abinjcy!
#
# Extracted LC features for ZTF19aatfqzb!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19aatfqzb!
#
# Extracted LC features for ZTF19abhzdjp!
# Saved results for ZTF19abhzdjp!
#
# Extracted LC features for ZTF19abgmxwn!
# Saved results for ZTF19abgmxwn!
#
# Extracted LC features for ZTF19abkgbul!
# Saved results for ZTF19abkgbul!
#
# Extracted LC features for ZTF19abkfxfb!
# Saved results for ZTF19abkfxfb!
#
# Extracted LC features for ZTF19abkfmjp!
# Saved results for ZTF19abkfmjp!
#
# Extracted LC features for ZTF19abkdehm!
# Some features are NaN for ZTF19abkdehm. Skip!
#
# Extracted LC features for ZTF19abjpkdz!
# Saved results for ZTF19abjpkdz!
#
# Extracted LC features for ZTF19abjibet!
# Saved results for ZTF19abjibet!
#
# Extracted LC features for ZTF19abjgdko!
# Saved results for ZTF19abjgdko!
#
# Extracted LC features for ZTF19abjamgc!
# Saved results for ZTF19abjamgc!
#
# Extracted LC features for ZTF19abirbpd!
# Saved results for ZTF19abirbpd!
#
# Extracted LC features for ZTF19abipmfl!
# Saved results for ZTF19abipmfl!
#
# Extracted LC features for ZTF19abidfsb!
# Saved results for ZTF19abidfsb!
#
# Extracted LC features for ZTF19abiahik!
# Saved results for ZTF19abiahik!
#
# Extracted LC features for ZTF19abhjhes!
# Saved results for ZTF19abhjhes!
#
# Extracted LC features for ZTF19abidbya!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abidbya!
#
# Extracted LC features for ZTF19abimkwn!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abimkwn!
#
# Extracted LC features for ZTF19abimlck!
# Saved results for ZTF19abimlck!
#
# Extracted LC features for ZTF19abgqwed!
# Saved results for ZTF19abgqwed!
#
# Extracted LC features for ZTF19abiqnpv!
# Saved results for ZTF19abiqnpv!
#
# Extracted LC features for ZTF19abioohk!
# Saved results for ZTF19abioohk!
#
# Extracted LC features for ZTF19abhphah!
# Saved results for ZTF19abhphah!
#
# Extracted LC features for ZTF19abgurml!
# Saved results for ZTF19abgurml!
#
# Extracted LC features for ZTF19abhztqq!
# Some features are NaN for ZTF19abhztqq. Skip!
#
# Extracted LC features for ZTF19abhdqlq!
# Saved results for ZTF19abhdqlq!
#
# Extracted LC features for ZTF19abgsyrp!
# Some features are NaN for ZTF19abgsyrp. Skip!
#
# Extracted LC features for ZTF19abhduuo!
# Saved results for ZTF19abhduuo!
#
# Extracted LC features for ZTF19abfvpkq!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19abfvpkq. Skip!
#
# Extracted LC features for ZTF19abguzsx!
# Saved results for ZTF19abguzsx!
#
# Extracted LC features for ZTF19abhpvfq!
# Saved results for ZTF19abhpvfq!
#
# No obs for ZTF18acdzpgs. pass!
#
# Extracted LC features for ZTF19abgppki!
# Saved results for ZTF19abgppki!
#
# Extracted LC features for ZTF19abfvovo!
# Saved results for ZTF19abfvovo!
#
# Extracted LC features for ZTF19abgbkwv!
# Some features are NaN for ZTF19abgbkwv. Skip!
#
# 250
# Extracted LC features for ZTF19abeyuxt!
# Saved results for ZTF19abeyuxt!
#
# Extracted LC features for ZTF19abggmim!
# Saved results for ZTF19abggmim!
#
# Extracted LC features for ZTF19abgfrbl!
# Saved results for ZTF19abgfrbl!
#
# Extracted LC features for ZTF19abhiayh!
# Some features are NaN for ZTF19abhiayh. Skip!
#
# Extracted LC features for ZTF19abgrcxs!
# Saved results for ZTF19abgrcxs!
#
# Extracted LC features for ZTF19abhdlxp!
# Saved results for ZTF19abhdlxp!
#
# Extracted LC features for ZTF19abgqvyr!
# Saved results for ZTF19abgqvyr!
#
# Extracted LC features for ZTF19abgprpq!
# Saved results for ZTF19abgprpq!
#
# Extracted LC features for ZTF18aarwxum!
# Saved results for ZTF18aarwxum!
#
# Extracted LC features for ZTF19abglmpf!
# Saved results for ZTF19abglmpf!
#
# Extracted LC features for ZTF19abgjlef!
# Saved results for ZTF19abgjlef!
#
# Extracted LC features for ZTF19abgiwkt!
# Saved results for ZTF19abgiwkt!
#
# Extracted LC features for ZTF19abgpgyp!
# Some features are NaN for ZTF19abgpgyp. Skip!
#
# Extracted LC features for ZTF19abgnuri!
# Saved results for ZTF19abgnuri!
#
# Extracted LC features for ZTF19abgcbey!
# Saved results for ZTF19abgcbey!
#
# Extracted LC features for ZTF19abgndlf!
# Saved results for ZTF19abgndlf!
#
# Extracted LC features for ZTF19abgncfz!
# Saved results for ZTF19abgncfz!
#
# Extracted LC features for ZTF19abfwhja!
# Saved results for ZTF19abfwhja!
#
# Extracted LC features for ZTF19abexfad!
# Saved results for ZTF19abexfad!
#
# Extracted LC features for ZTF19abfdszw!
# Saved results for ZTF19abfdszw!
#
# Extracted LC features for ZTF19abfhszx!
# Some features are NaN for ZTF19abfhszx. Skip!
#
# Extracted LC features for ZTF19abfiqjg!
# Saved results for ZTF19abfiqjg!
#
# Extracted LC features for ZTF19abeytzv!
# Saved results for ZTF19abeytzv!
#
# Extracted LC features for ZTF19abfdsbu!
# Saved results for ZTF19abfdsbu!
#
# Extracted LC features for ZTF19abfaqqo!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abfaqqo!
#
# Extracted LC features for ZTF19abgmkef!
# Saved results for ZTF19abgmkef!
#
# Extracted LC features for ZTF19abfwfei!
# Saved results for ZTF19abfwfei!
#
# Not enough obs for ZTF19abfwdyt. pass!
#
# Extracted LC features for ZTF19abdmdow!
# Saved results for ZTF19abdmdow!
#
# Not enough obs for ZTF19abdehcz. pass!
#
# Extracted LC features for ZTF19abfvhlx!
# Saved results for ZTF19abfvhlx!
#
# Extracted LC features for ZTF19abfwtkw!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19abfwtkw. Skip!
#
# Extracted LC features for ZTF19abfsxpw!
# Saved results for ZTF19abfsxpw!
#
# Extracted LC features for ZTF19abgbdcp!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abgbdcp!
#
# No obs for ZTF19abfjjlk. pass!
#
# Extracted LC features for ZTF19abdzehg!
# Saved results for ZTF19abdzehg!
#
# Extracted LC features for ZTF19abdmfgf!
# Saved results for ZTF19abdmfgf!
#
# Extracted LC features for ZTF19abfqhis!
# Saved results for ZTF19abfqhis!
#
# Extracted LC features for ZTF19abdkcib!
# Saved results for ZTF19abdkcib!
#
# Extracted LC features for ZTF18abdcudb!
# Some features are NaN for ZTF18abdcudb. Skip!
#
# Extracted LC features for ZTF19abeloei!
# Some features are NaN for ZTF19abeloei. Skip!
#
# Extracted LC features for ZTF19abdyawn!
# Saved results for ZTF19abdyawn!
#
# Extracted LC features for ZTF19abfibel!
# Saved results for ZTF19abfibel!
#
# Extracted LC features for ZTF19aaynqaj!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF19aaynqaj. Skip!
#
# Extracted LC features for ZTF19aaserwb!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aaserwb. Skip!
#
# Extracted LC features for ZTF19aaruixj!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aaruixj!
#
# Extracted LC features for ZTF19aaqrime!
# Saved results for ZTF19aaqrime!
#
# Extracted LC features for ZTF19aamhhiz!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aamhhiz!
#
# Extracted LC features for ZTF19aalvdeu!
# Saved results for ZTF19aalvdeu!
#
# Extracted LC features for ZTF19aalbrph!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aalbrph. Skip!
#
# 300
# Extracted LC features for ZTF19abetjcx!
# Saved results for ZTF19abetjcx!
#
# Extracted LC features for ZTF19abcunya!
# Saved results for ZTF19abcunya!
#
# Extracted LC features for ZTF19abdoznh!
# Saved results for ZTF19abdoznh!
#
# Extracted LC features for ZTF19abdoior!
# Saved results for ZTF19abdoior!
#
# Extracted LC features for ZTF19abdviwl!
# Saved results for ZTF19abdviwl!
#
# No obs for ZTF19abejaiy. pass!
#
# Not enough obs for ZTF19abdsqmf. pass!
#
# Extracted LC features for ZTF19abdkgns!
# Saved results for ZTF19abdkgns!
#
# Extracted LC features for ZTF19abdkdir!
# Saved results for ZTF19abdkdir!
#
# Not enough obs for ZTF19abdjwtv. pass!
#
# Extracted LC features for ZTF19abcfzdy!
# Saved results for ZTF19abcfzdy!
#
# Extracted LC features for ZTF19abdznxo!
# Saved results for ZTF19abdznxo!
#
# Extracted LC features for ZTF19abdkecj!
# Saved results for ZTF19abdkecj!
#
# Extracted LC features for ZTF19abdduix!
# Saved results for ZTF19abdduix!
#
# Extracted LC features for ZTF19abctnpk!
# Saved results for ZTF19abctnpk!
#
# Extracted LC features for ZTF19abdqaao!
# Saved results for ZTF19abdqaao!
#
# Extracted LC features for ZTF19abdkgwo!
# Saved results for ZTF19abdkgwo!
#
# Extracted LC features for ZTF19abdjsss!
# Saved results for ZTF19abdjsss!
#
# Extracted LC features for ZTF19abcejoa!
# Saved results for ZTF19abcejoa!
#
# Extracted LC features for ZTF19abaukyt!
# Saved results for ZTF19abaukyt!
#
# Extracted LC features for ZTF19abaeyqw!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abaeyqw!
#
# Extracted LC features for ZTF19abbxykm!
# Saved results for ZTF19abbxykm!
#
# Extracted LC features for ZTF19abcekty!
# Saved results for ZTF19abcekty!
#
# Extracted LC features for ZTF19abcejsg!
# Saved results for ZTF19abcejsg!
#
# Extracted LC features for ZTF19abcejfo!
# Saved results for ZTF19abcejfo!
#
# Extracted LC features for ZTF19abcegvm!
# Saved results for ZTF19abcegvm!
#
# Extracted LC features for ZTF19abaesgr!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19abaesgr!
#
# Extracted LC features for ZTF19abcneik!
# Saved results for ZTF19abcneik!
#
# Extracted LC features for ZTF19abcndvf!
# Saved results for ZTF19abcndvf!
#
# Not enough obs for ZTF19abbywep. pass!
#
# Not enough obs for ZTF19abbytxa. pass!
#
# Extracted LC features for ZTF19abanfrn!
# Saved results for ZTF19abanfrn!
#
# Extracted LC features for ZTF19aazlpel!
# Saved results for ZTF19aazlpel!
#
# No obs for ZTF19abatvzs. pass!
#
# Extracted LC features for ZTF19abatvit!
# Saved results for ZTF19abatvit!
#
# Extracted LC features for ZTF19abbthwy!
# Saved results for ZTF19abbthwy!
#
# Extracted LC features for ZTF19abaosan!
# Saved results for ZTF19abaosan!
#
# Extracted LC features for ZTF19abangub!
# Saved results for ZTF19abangub!
#
# Extracted LC features for ZTF19abanayw!
# Saved results for ZTF19abanayw!
#
# Extracted LC features for ZTF19aazdirb!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aazdirb. Skip!
#
# Extracted LC features for ZTF19abamqxo!
# Saved results for ZTF19abamqxo!
#
# Extracted LC features for ZTF19abauylg!
# Some features are NaN for ZTF19abauylg. Skip!
#
# Extracted LC features for ZTF19abakjci!
# Saved results for ZTF19abakjci!
#
# No obs for ZTF19abakdjd. pass!
#
# Extracted LC features for ZTF19abafmwj!
# Saved results for ZTF19abafmwj!
#
# Extracted LC features for ZTF19abaejrh!
# Saved results for ZTF19abaejrh!
#
# Extracted LC features for ZTF19abafrvy!
# Saved results for ZTF19abafrvy!
#
# Not enough obs for ZTF19abahsdc. pass!
#
# Extracted LC features for ZTF19abajuqh!
# Saved results for ZTF19abajuqh!
#
# Extracted LC features for ZTF19abasxkg!
# Saved results for ZTF19abasxkg!
#
# 350
# Extracted LC features for ZTF19aazdcmj!
# Saved results for ZTF19aazdcmj!
#
# Extracted LC features for ZTF19abangws!
# Some features are NaN for ZTF19abangws. Skip!
#
# Extracted LC features for ZTF19abandzh!
# Saved results for ZTF19abandzh!
#
# Extracted LC features for ZTF19abattvp!
# Saved results for ZTF19abattvp!
#
# Extracted LC features for ZTF19ababigc!
# Saved results for ZTF19ababigc!
#
# Extracted LC features for ZTF19aazpkyv!
# Saved results for ZTF19aazpkyv!
#
# Extracted LC features for ZTF19abalrbb!
# Saved results for ZTF19abalrbb!
#
# Extracted LC features for ZTF19aayveer!
# Saved results for ZTF19aayveer!
#
# Extracted LC features for ZTF19abaejto!
# Saved results for ZTF19abaejto!
#
# Extracted LC features for ZTF19abahsgg!
# Saved results for ZTF19abahsgg!
#
# Extracted LC features for ZTF19ababmsi!
# Saved results for ZTF19ababmsi!
#
# Extracted LC features for ZTF19abahvdh!
# Saved results for ZTF19abahvdh!
#
# Extracted LC features for ZTF19aavvvrc!
# Saved results for ZTF19aavvvrc!
#
# Extracted LC features for ZTF19abaeyln!
# Saved results for ZTF19abaeyln!
#
# No obs for ZTF19abacxwt. pass!
#
# Extracted LC features for ZTF19abacxod!
# Saved results for ZTF19abacxod!
#
# Not enough obs for ZTF19aaxkhxw. pass!
#
# Extracted LC features for ZTF19aazzpje!
# Saved results for ZTF19aazzpje!
#
# Extracted LC features for ZTF19aaypehm!
# Saved results for ZTF19aaypehm!
#
# Extracted LC features for ZTF19aavsrgj!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aavsrgj. Skip!
#
# Extracted LC features for ZTF19abadskf!
# Saved results for ZTF19abadskf!
#
# Extracted LC features for ZTF19aazxcvl!
# Saved results for ZTF19aazxcvl!
#
# Extracted LC features for ZTF19aazwnwy!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aazwnwy!
#
# Extracted LC features for ZTF19aazpvyr!
# Saved results for ZTF19aazpvyr!
#
# Extracted LC features for ZTF19aayckwk!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aayckwk. Skip!
#
# Extracted LC features for ZTF19aayqait!
# Saved results for ZTF19aayqait!
#
# Extracted LC features for ZTF19aawqcgy!
# Some features are NaN for ZTF19aawqcgy. Skip!
#
# Extracted LC features for ZTF19aayvylv!
# Saved results for ZTF19aayvylv!
#
# Extracted LC features for ZTF19aayrosj!
# Saved results for ZTF19aayrosj!
#
# Extracted LC features for ZTF19aaywtoc!
# Saved results for ZTF19aaywtoc!
#
# Extracted LC features for ZTF19aazudta!
# Saved results for ZTF19aazudta!
#
# Extracted LC features for ZTF19aazlsfj!
# Saved results for ZTF19aazlsfj!
#
# Extracted LC features for ZTF19aaziick!
# Saved results for ZTF19aaziick!
#
# Extracted LC features for ZTF19aaywlmi!
# Saved results for ZTF19aaywlmi!
#
# Extracted LC features for ZTF19aazfvhh!
# Saved results for ZTF19aazfvhh!
#
# Extracted LC features for ZTF19aazpvdy!
# Saved results for ZTF19aazpvdy!
#
# Extracted LC features for ZTF19aayslow!
# Saved results for ZTF19aayslow!
#
# Extracted LC features for ZTF19aaysiwt!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aaysiwt!
#
# Not enough obs for ZTF19aayshvd. pass!
#
# Extracted LC features for ZTF19aayrjnf!
# Saved results for ZTF19aayrjnf!
#
# Extracted LC features for ZTF19aazgpar!
# Saved results for ZTF19aazgpar!
#
# Extracted LC features for ZTF19aavjzrz!
# Some features are NaN for ZTF19aavjzrz. Skip!
#
# Extracted LC features for ZTF19aaycrgf!
# Saved results for ZTF19aaycrgf!
#
# Extracted LC features for ZTF19aawblge!
# Saved results for ZTF19aawblge!
#
# Extracted LC features for ZTF19aaydpiq!
# Saved results for ZTF19aaydpiq!
#
# Extracted LC features for ZTF19aavjukt!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aavjukt. Skip!
#
# Extracted LC features for ZTF19aaxfzao!
# Some features are NaN for ZTF19aaxfzao. Skip!
#
# Extracted LC features for ZTF19aayejww!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aayejww!
#
# Extracted LC features for ZTF19aaxyukr!
# Saved results for ZTF19aaxyukr!
#
# Extracted LC features for ZTF19aawfbtg!
# Saved results for ZTF19aawfbtg!
#
# 400
# Extracted LC features for ZTF19aayfaum!
# Saved results for ZTF19aayfaum!
#
# Extracted LC features for ZTF19aayabqe!
# Saved results for ZTF19aayabqe!
#
# Extracted LC features for ZTF19aayjsty!
# Saved results for ZTF19aayjsty!
#
# Extracted LC features for ZTF19aaxptsd!
# Saved results for ZTF19aaxptsd!
#
# Extracted LC features for ZTF19aaxnlps!
# Saved results for ZTF19aaxnlps!
#
# Extracted LC features for ZTF19aaxibby!
# Saved results for ZTF19aaxibby!
#
# Extracted LC features for ZTF19aawsday!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aawsday. Skip!
#
# Extracted LC features for ZTF19aaycomi!
# Saved results for ZTF19aaycomi!
#
# Extracted LC features for ZTF19aawyepw!
# Saved results for ZTF19aawyepw!
#
# Extracted LC features for ZTF19aawtqdv!
# Some features are NaN for ZTF19aawtqdv. Skip!
#
# Extracted LC features for ZTF19aaxpjpq!
# Saved results for ZTF19aaxpjpq!
#
# Extracted LC features for ZTF19aawrumx!
# Saved results for ZTF19aawrumx!
#
# Extracted LC features for ZTF19aavvozj!
# Saved results for ZTF19aavvozj!
#
# Extracted LC features for ZTF19aavqics!
# Saved results for ZTF19aavqics!
#
# Extracted LC features for ZTF19aawqckx!
# Saved results for ZTF19aawqckx!
#
# Extracted LC features for ZTF19aawupxb!
# Saved results for ZTF19aawupxb!
#
# Extracted LC features for ZTF19aaxibpz!
# Saved results for ZTF19aaxibpz!
#
# Extracted LC features for ZTF19aaxhysx!
# Some features are NaN for ZTF19aaxhysx. Skip!
#
# Extracted LC features for ZTF19aawmqtd!
# Saved results for ZTF19aawmqtd!
#
# Extracted LC features for ZTF19aawmkja!
# Saved results for ZTF19aawmkja!
#
# Extracted LC features for ZTF19aaxfcpq!
# Saved results for ZTF19aaxfcpq!
#
# Extracted LC features for ZTF19aawafvn!
# Saved results for ZTF19aawafvn!
#
# Extracted LC features for ZTF19aaxffum!
# Saved results for ZTF19aaxffum!
#
# Not enough obs for ZTF19aaxeaag. pass!
#
# Extracted LC features for ZTF19aawhniz!
# Saved results for ZTF19aawhniz!
#
# Extracted LC features for ZTF19aavivbl!
# Saved results for ZTF19aavivbl!
#
# Extracted LC features for ZTF19aawudku!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19aawudku!
#
# Extracted LC features for ZTF19aavwbpc!
# Saved results for ZTF19aavwbpc!
#
# Extracted LC features for ZTF19aavyafo!
# Saved results for ZTF19aavyafo!
#
# Extracted LC features for ZTF19aavxfib!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aavxfib!
#
# Extracted LC features for ZTF19aawtnqd!
# Saved results for ZTF19aawtnqd!
#
# Extracted LC features for ZTF19aavnzti!
# Saved results for ZTF19aavnzti!
#
# Extracted LC features for ZTF19aavtcjs!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aavtcjs. Skip!
#
# Extracted LC features for ZTF19aavaikm!
# Saved results for ZTF19aavaikm!
#
# Extracted LC features for ZTF19aavkptg!
# Saved results for ZTF19aavkptg!
#
# Extracted LC features for ZTF19aawgxdn!
# Saved results for ZTF19aawgxdn!
#
# Extracted LC features for ZTF19aavorpa!
# Saved results for ZTF19aavorpa!
#
# Extracted LC features for ZTF19aawgolt!
# Saved results for ZTF19aawgolt!
#
# Extracted LC features for ZTF19aavnxwj!
# Saved results for ZTF19aavnxwj!
#
# Extracted LC features for ZTF19aawfkeg!
# Saved results for ZTF19aawfkeg!
#
# Extracted LC features for ZTF18aarlukc!
# Saved results for ZTF18aarlukc!
#
# Extracted LC features for ZTF19aavxpbx!
# Saved results for ZTF19aavxpbx!
#
# Extracted LC features for ZTF19aavxikq!
# Saved results for ZTF19aavxikq!
#
# Extracted LC features for ZTF19aavounq!
# Saved results for ZTF19aavounq!
#
# Extracted LC features for ZTF19aavqoyu!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aavqoyu. Skip!
#
# Extracted LC features for ZTF19aavqotz!
# Saved results for ZTF19aavqotz!
#
# Extracted LC features for ZTF19aavqoop!
# Saved results for ZTF19aavqoop!
#
# Extracted LC features for ZTF19aavnwtf!
# Saved results for ZTF19aavnwtf!
#
# Extracted LC features for ZTF19aavrswr!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aavrswr!
#
# Extracted LC features for ZTF19aavlnjz!
# Saved results for ZTF19aavlnjz!
#
# 450
# Extracted LC features for ZTF19aavhwxs!
# Saved results for ZTF19aavhwxs!
#
# Extracted LC features for ZTF19aavnuur!
# Saved results for ZTF19aavnuur!
#
# Extracted LC features for ZTF19aavmgtv!
# Saved results for ZTF19aavmgtv!
#
# Extracted LC features for ZTF19aavkvpw!
# Saved results for ZTF19aavkvpw!
#
# Extracted LC features for ZTF19aavnwyt!
# Saved results for ZTF19aavnwyt!
#
# Extracted LC features for ZTF19aavnwxf!
# Saved results for ZTF19aavnwxf!
#
# Extracted LC features for ZTF19aaurstb!
# Saved results for ZTF19aaurstb!
#
# Extracted LC features for ZTF18aavuziy!
# Saved results for ZTF18aavuziy!
#
# Extracted LC features for ZTF19aavmlqh!
# Saved results for ZTF19aavmlqh!
#
# Extracted LC features for ZTF19aavjlkx!
# Saved results for ZTF19aavjlkx!
#
# Extracted LC features for ZTF19aavidqf!
# Saved results for ZTF19aavidqf!
#
# Extracted LC features for ZTF19aavlfvn!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aavlfvn. Skip!
#
# Extracted LC features for ZTF19aavhypb!
# Saved results for ZTF19aavhypb!
#
# Extracted LC features for ZTF18aaoufjt!
# Saved results for ZTF18aaoufjt!
#
# Extracted LC features for ZTF19aauvjws!
# Saved results for ZTF19aauvjws!
#
# Extracted LC features for ZTF19aaupkev!
# Saved results for ZTF19aaupkev!
#
# Extracted LC features for ZTF19aavbjfp!
# Saved results for ZTF19aavbjfp!
#
# Extracted LC features for ZTF19aaurhox!
# Saved results for ZTF19aaurhox!
#
# Extracted LC features for ZTF19aauoulb!
# Saved results for ZTF19aauoulb!
#
# Extracted LC features for ZTF19aauxepf!
# Saved results for ZTF19aauxepf!
#
# No obs for ZTF19aatmgjs. pass!
#
# Not enough obs for ZTF19aauvlxk. pass!
#
# Extracted LC features for ZTF19aasmddt!
# Saved results for ZTF19aasmddt!
#
# Extracted LC features for ZTF19aauxxgk!
# Saved results for ZTF19aauxxgk!
#
# Extracted LC features for ZTF19aauqywe!
# Saved results for ZTF19aauqywe!
#
# Extracted LC features for ZTF19aauvkxu!
# Saved results for ZTF19aauvkxu!
#
# Extracted LC features for ZTF19aauvbqv!
# Some features are NaN for ZTF19aauvbqv. Skip!
#
# Extracted LC features for ZTF19aauuzlr!
# Saved results for ZTF19aauuzlr!
#
# Extracted LC features for ZTF19aaumvig!
# Some features are NaN for ZTF19aaumvig. Skip!
#
# Extracted LC features for ZTF19aaujzqh!
# Saved results for ZTF19aaujzqh!
#
# Extracted LC features for ZTF19aaupkrl!
# Saved results for ZTF19aaupkrl!
#
# Extracted LC features for ZTF19aauplxw!
# Saved results for ZTF19aauplxw!
#
# Extracted LC features for ZTF19aauitks!
# Saved results for ZTF19aauitks!
#
# Extracted LC features for ZTF18aaqkcso!
# Some features are NaN for ZTF18aaqkcso. Skip!
#
# Extracted LC features for ZTF19aauisdr!
# Saved results for ZTF19aauisdr!
#
# Extracted LC features for ZTF19aauhwbp!
# Saved results for ZTF19aauhwbp!
#
# Extracted LC features for ZTF19aatnfvj!
# Saved results for ZTF19aatnfvj!
#
# Extracted LC features for ZTF19aaujiwc!
# Saved results for ZTF19aaujiwc!
#
# Extracted LC features for ZTF19aauishy!
# Some features are NaN for ZTF19aauishy. Skip!
#
# Extracted LC features for ZTF19aaugaam!
# Saved results for ZTF19aaugaam!
#
# Extracted LC features for ZTF19aauguzk!
# Saved results for ZTF19aauguzk!
#
# Extracted LC features for ZTF19aaugoig!
# Saved results for ZTF19aaugoig!
#
# Extracted LC features for ZTF19aatvljp!
# Saved results for ZTF19aatvljp!
#
# Extracted LC features for ZTF19aargqez!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aargqez!
#
# Extracted LC features for ZTF19aaqyvdn!
# Some features are NaN for ZTF19aaqyvdn. Skip!
#
# Extracted LC features for ZTF19aatzlmw!
# Saved results for ZTF19aatzlmw!
#
# Extracted LC features for ZTF19aatqzim!
# Saved results for ZTF19aatqzim!
#
# Extracted LC features for ZTF18aaqkdwu!
# Saved results for ZTF18aaqkdwu!
#
# Extracted LC features for ZTF19aatvmbo!
# Saved results for ZTF19aatvmbo!
#
# Extracted LC features for ZTF19aasszud!
# Saved results for ZTF19aasszud!
#
# 500
# Extracted LC features for ZTF19aatvlfl!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aatvlfl!
#
# Extracted LC features for ZTF19aatvkrn!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aatvkrn. Skip!
#
# Extracted LC features for ZTF19aatudsq!
# Saved results for ZTF19aatudsq!
#
# Extracted LC features for ZTF19aarxrem!
# Saved results for ZTF19aarxrem!
#
# Extracted LC features for ZTF19aasfsoi!
# Saved results for ZTF19aasfsoi!
#
# Not enough obs for ZTF19aatgaiq. pass!
#
# Extracted LC features for ZTF19aatnefp!
# Saved results for ZTF19aatnefp!
#
# Extracted LC features for ZTF19aatgznl!
# Saved results for ZTF19aatgznl!
#
# Extracted LC features for ZTF19aatlqdf!
# Saved results for ZTF19aatlqdf!
#
# Extracted LC features for ZTF19aasekcx!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aasekcx!
#
# Extracted LC features for ZTF18aaxokeg!
# Saved results for ZTF18aaxokeg!
#
# Extracted LC features for ZTF19aathllr!
# Saved results for ZTF19aathllr!
#
# Extracted LC features for ZTF19aassqix!
# Saved results for ZTF19aassqix!
#
# Extracted LC features for ZTF19aarqmjs!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19aarqmjs!
#
# Extracted LC features for ZTF19aarhhfx!
# Saved results for ZTF19aarhhfx!
#
# Extracted LC features for ZTF19aartylj!
# Saved results for ZTF19aartylj!
#
# Extracted LC features for ZTF19aarixue!
# Saved results for ZTF19aarixue!
#
# Extracted LC features for ZTF19aarifvr!
# Some features are NaN for ZTF19aarifvr. Skip!
#
# Extracted LC features for ZTF19aaripqw!
# Saved results for ZTF19aaripqw!
#
# No obs for ZTF19aarzaod. pass!
#
# Extracted LC features for ZTF19aartuli!
# Saved results for ZTF19aartuli!
#
# Extracted LC features for ZTF19aartuev!
# Saved results for ZTF19aartuev!
#
# Extracted LC features for ZTF19aarykkb!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19aarykkb!
#
# No obs for ZTF19aarilal. pass!
#
# Extracted LC features for ZTF19aarnqys!
# Saved results for ZTF19aarnqys!
#
# Extracted LC features for ZTF19aapvogv!
# Saved results for ZTF19aapvogv!
#
# Extracted LC features for ZTF19aarprog!
# Saved results for ZTF19aarprog!
#
# Extracted LC features for ZTF19aarnrbw!
# Saved results for ZTF19aarnrbw!
#
# Extracted LC features for ZTF19aarnqzw!
# Saved results for ZTF19aarnqzw!
#
# Extracted LC features for ZTF19aarkpif!
# Saved results for ZTF19aarkpif!
#
# Extracted LC features for ZTF19aarmznp!
# Saved results for ZTF19aarmznp!
#
# Extracted LC features for ZTF19aarfyvc!
# Saved results for ZTF19aarfyvc!
#
# Extracted LC features for ZTF19aapzbjr!
# Saved results for ZTF19aapzbjr!
#
# Extracted LC features for ZTF19aaoxfyh!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aaoxfyh. Skip!
#
# Extracted LC features for ZTF19aaqtcmy!
# Saved results for ZTF19aaqtcmy!
#
# Extracted LC features for ZTF19aarfksi!
# Saved results for ZTF19aarfksi!
#
# Extracted LC features for ZTF19aariwpf!
# Some features are NaN for ZTF19aariwpf. Skip!
#
# Extracted LC features for ZTF19aarinmw!
# Saved results for ZTF19aarinmw!
#
# Extracted LC features for ZTF19aaraxhh!
# Saved results for ZTF19aaraxhh!
#
# Extracted LC features for ZTF19aarflsx!
# Saved results for ZTF19aarflsx!
#
# Extracted LC features for ZTF19aarhxgn!
# Saved results for ZTF19aarhxgn!
#
# Extracted LC features for ZTF19aaraued!
# Saved results for ZTF19aaraued!
#
# Extracted LC features for ZTF19aapreis!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF19aapreis!
#
# Extracted LC features for ZTF19aarfnto!
# Saved results for ZTF19aarfnto!
#
# Extracted LC features for ZTF19aaqxcfs!
# Saved results for ZTF19aaqxcfs!
#
# Extracted LC features for ZTF19aaqhelq!
# Saved results for ZTF19aaqhelq!
#
# Extracted LC features for ZTF19aapxocr!
# Saved results for ZTF19aapxocr!
#
# Not enough obs for ZTF19aaqgnhf. pass!
#
# Extracted LC features for ZTF19aardunx!
# Saved results for ZTF19aardunx!
#
# Extracted LC features for ZTF19aaqcqkv!
# Saved results for ZTF19aaqcqkv!
#
# 550
# Extracted LC features for ZTF19aapwbvm!
# Saved results for ZTF19aapwbvm!
#
# Extracted LC features for ZTF19aaqxosb!
# Some features are NaN for ZTF19aaqxosb. Skip!
#
# Extracted LC features for ZTF19aaqdkrm!
# Saved results for ZTF19aaqdkrm!
#
# Extracted LC features for ZTF19aaqasrq!
# Saved results for ZTF19aaqasrq!
#
# Extracted LC features for ZTF19aaohuwc!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aaohuwc. Skip!
#
# Extracted LC features for ZTF19aapvhhp!
# Saved results for ZTF19aapvhhp!
#
# Extracted LC features for ZTF19aaptwpu!
# Saved results for ZTF19aaptwpu!
#
# Extracted LC features for ZTF19aapceyj!
# Saved results for ZTF19aapceyj!
#
# Extracted LC features for ZTF19aapocyd!
# Saved results for ZTF19aapocyd!
#
# Extracted LC features for ZTF19aapnzde!
# ...
#
# Extracted LC features for ZTF19aailmfm!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF19aailmfm!
#
# Not enough obs for ZTF19aadnsqj. pass!
#
# Extracted LC features for ZTF19aafmvdb!
# Saved results for ZTF19aafmvdb!
#
# Extracted LC features for ZTF19aafmfxg!
# Saved results for ZTF19aafmfxg!
#
# Extracted LC features for ZTF19aafnfyc!
# Saved results for ZTF19aafnfyc!
#
# Extracted LC features for ZTF19aafnecv!
# Saved results for ZTF19aafnecv!
#
# Extracted LC features for ZTF19aafmwfc!
# Saved results for ZTF19aafmwfc!
#
# Extracted LC features for ZTF19aaeoqst!
# Saved results for ZTF19aaeoqst!
#
# Not enough obs for ZTF19aaeoqqj. pass!
#
# Extracted LC features for ZTF19aafljiq!
# Saved results for ZTF19aafljiq!
#
# Extracted LC features for ZTF19aadyijk!
# Saved results for ZTF19aadyijk!
#
# Extracted LC features for ZTF19aaejtof!
# Saved results for ZTF19aaejtof!
#
# Extracted LC features for ZTF19aadyppr!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aadyppr. Skip!
#
# Extracted LC features for ZTF19aaeopqn!
# Saved results for ZTF19aaeopqn!
#
# Extracted LC features for ZTF18aaermez!
# Saved results for ZTF18aaermez!
#
# Extracted LC features for ZTF19aadwtoe!
# Some features are NaN for ZTF19aadwtoe. Skip!
# Extracted LC features for ZTF19aaeicsm!
# Saved results for ZTF19aaeicsm!
#
# Extracted LC features for ZTF19aadtqcd!
# Some features are NaN for ZTF19aadtqcd. Skip!
#
# Extracted LC features for ZTF19aadypig!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF19aadypig. Skip!
#
# Extracted LC features for ZTF19aadttht!
# Some features are NaN for ZTF19aadttht. Skip!
#
# Extracted LC features for ZTF19aadolpe!
# Saved results for ZTF19aadolpe!
#
# Extracted LC features for ZTF19aadoocn!
# Saved results for ZTF19aadoocn!
#
# Not enough obs for ZTF19aadpdqm. pass!
#
# Extracted LC features for ZTF19aadnwbv!
# Some features are NaN for ZTF19aadnwbv. Skip!
#
# Extracted LC features for ZTF19aadnxgj!
# Saved results for ZTF19aadnxgj!
#
# Not enough obs for ZTF19aaddzpk. pass!
#
# Extracted LC features for ZTF19aacwljg!
# Saved results for ZTF19aacwljg!
#
# Not enough obs for ZTF19aacigpk. pass!
#
# Not enough obs for ZTF19aaactno. pass!
#
# Not enough obs for ZTF19aaaonuk. pass!
#
# Extracted LC features for ZTF18adcakbo!
# Some features are NaN for ZTF18adcakbo. Skip!
#
# Extracted LC features for ZTF18aarmnnd!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF18aarmnnd!
#
# Extracted LC features for ZTF18aazgrfl!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF18aazgrfl!
#
# Extracted LC features for ZTF18abddjpt!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Some features are NaN for ZTF18abddjpt. Skip!
#
# Extracted LC features for ZTF18aayxxew!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18aayxxew!
#
# Extracted LC features for ZTF18aarqxbw!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF18aarqxbw!
#
# No obs for ZTF18aaxzlmy. pass!
#
# Extracted LC features for ZTF18abquyqj!
# Found 2 hosts in GLADE! See gladeDLR.txt for details.
# Found matches for 50.0% of events.
# Saved results for ZTF18abquyqj!
#
# No obs for ZTF18abttsrb. pass!
#
# Extracted LC features for ZTF18abmxelh!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF18abmxelh. Skip!
#
# Extracted LC features for ZTF18abqbavl!
# Saved results for ZTF18abqbavl!
#
# Extracted LC features for ZTF18aboaeqy!
# Saved results for ZTF18aboaeqy!
#
# Not enough obs for ZTF18aasesgl. pass!
#
# Extracted LC features for ZTF18abslxhz!
# Some features are NaN for ZTF18abslxhz. Skip!
#
# 800
# Extracted LC features for ZTF18abklljv!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18abklljv!
#
# Extracted LC features for ZTF18abixjey!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Some features are NaN for ZTF18abixjey. Skip!
#
# Extracted LC features for ZTF18abealop!
# Saved results for ZTF18abealop!
#
# Extracted LC features for ZTF18abdmgab!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18abdmgab!
#
# Extracted LC features for ZTF18abclalx!
# Saved results for ZTF18abclalx!
#
# Extracted LC features for ZTF18abatffv!
# Saved results for ZTF18abatffv!
#
# Extracted LC features for ZTF18aaxrvzj!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18aaxrvzj!
#
# Extracted LC features for ZTF18aarldnh!
# Saved results for ZTF18aarldnh!
#
# Extracted LC features for ZTF18aaunfqq!
# Saved results for ZTF18aaunfqq!
#
# Extracted LC features for ZTF18adazeua!
# Saved results for ZTF18adazeua!
#
# Not enough obs for ZTF18adalhga. pass!
#
# Extracted LC features for ZTF18adaykvg!
# Saved results for ZTF18adaykvg!
#
# No obs for ZTF18acynoro. pass!
#
# Not enough obs for ZTF18acvcxnc. pass!
#
# Not enough obs for ZTF18acusueb. pass!
#
# Not enough obs for ZTF18acsoyiu. pass!
#
# Not enough obs for ZTF18achjcwv. pass!
#
# Not enough obs for ZTF18acrfklz. pass!
#
# No obs for ZTF18acceprh. pass!
#
# Not enough obs for ZTF18acrheel. pass!
#
# No obs for ZTF18achdzwk. pass!
#
# Not enough obs for ZTF18acbwglw. pass!
#
# Extracted LC features for ZTF18aamsgjq!
# Saved results for ZTF18aamsgjq!
#
# Not enough obs for ZTF18acaqcdg. pass!
#
# Not enough obs for ZTF18acbxkpa. pass!
#
# Extracted LC features for ZTF18aaemivw!
# Saved results for ZTF18aaemivw!
#
# Extracted LC features for ZTF18acbwtnh!
# Some features are NaN for ZTF18acbwtnh. Skip!
#
# Extracted LC features for ZTF18acbwavp!
# Saved results for ZTF18acbwavp!
#
# Extracted LC features for ZTF18aawozzj!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18aawozzj!
#
# Extracted LC features for ZTF18abwwfyo!
# Saved results for ZTF18abwwfyo!
#
# Not enough obs for ZTF18abwmuua. pass!
#
# No obs for ZTF18abwcooy. pass!
#
# No obs for ZTF18abwerpm. pass!
#
# No obs for ZTF18abwckzf. pass!
#
# No obs for ZTF18abwclem. pass!
#
# No obs for ZTF18abuqhje. pass!
#
# Extracted LC features for ZTF18abojpnr!
# Saved results for ZTF18abojpnr!
#
# Extracted LC features for ZTF18absnqyo!
# Saved results for ZTF18absnqyo!
#
# Extracted LC features for ZTF18abshmro!
# Saved results for ZTF18abshmro!
#
# No obs for ZTF18abscyjj. pass!
#
# Not enough obs for ZTF18absdbvf. pass!
#
# Not enough obs for ZTF18aboabxv. pass!
#
# Extracted LC features for ZTF18abqdadp!
# Saved results for ZTF18abqdadp!
#
# Extracted LC features for ZTF18abqbuaj!
# Saved results for ZTF18abqbuaj!
#
# Extracted LC features for ZTF18abmjvpb!
# Saved results for ZTF18abmjvpb!
#
# Extracted LC features for ZTF18abobkii!
# Saved results for ZTF18abobkii!
#
# Extracted LC features for ZTF18abmjvuf!
# Saved results for ZTF18abmjvuf!
#
# Extracted LC features for ZTF18ablqkud!
# Saved results for ZTF18ablqkud!
#
# Extracted LC features for ZTF18abmxmsv!
# Saved results for ZTF18abmxmsv!
#
# Extracted LC features for ZTF18abfdupq!
# Saved results for ZTF18abfdupq!
#
# 850
# Extracted LC features for ZTF18abmrhom!
# Saved results for ZTF18abmrhom!
#
# Not enough obs for ZTF18ablqhqx. pass!
#
# Extracted LC features for ZTF18abmmkaz!
# Some features are NaN for ZTF18abmmkaz. Skip!
#
# Extracted LC features for ZTF18ablhvfr!
# Saved results for ZTF18ablhvfr!
#
# Extracted LC features for ZTF18ablqlzp!
# Saved results for ZTF18ablqlzp!
#
# Extracted LC features for ZTF18ablongw!
# Saved results for ZTF18ablongw!
#
# Extracted LC features for ZTF18ablwtkf!
# Saved results for ZTF18ablwtkf!
#
# Not enough obs for ZTF18abjstcm. pass!
#
# Extracted LC features for ZTF18abjyjdz!
# Saved results for ZTF18abjyjdz!
#
# Extracted LC features for ZTF18abjdjge!
# Saved results for ZTF18abjdjge!
#
# Extracted LC features for ZTF18abktphg!
# Saved results for ZTF18abktphg!
#
# Extracted LC features for ZTF18abjyime!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18abjyime!
#
# Extracted LC features for ZTF18abkjnqy!
# Saved results for ZTF18abkjnqy!
#
# Extracted LC features for ZTF18ablqehq!
# Saved results for ZTF18ablqehq!
#
# Extracted LC features for ZTF18abkifng!
# Saved results for ZTF18abkifng!
#
# Extracted LC features for ZTF18abjtger!
# Saved results for ZTF18abjtger!
#
# Extracted LC features for ZTF18abdfwur!
# Saved results for ZTF18abdfwur!
#
# Extracted LC features for ZTF18abjtgdo!
# Saved results for ZTF18abjtgdo!
#
# Extracted LC features for ZTF18abimsyv!
# Saved results for ZTF18abimsyv!
#
# Extracted LC features for ZTF18abkhbra!
# Some features are NaN for ZTF18abkhbra. Skip!
#
# Extracted LC features for ZTF18abjvhec!
# Saved results for ZTF18abjvhec!
#
# Extracted LC features for ZTF18abkhcwl!
# Saved results for ZTF18abkhcwl!
#
# Extracted LC features for ZTF18abhhnnv!
# Saved results for ZTF18abhhnnv!
#
# Extracted LC features for ZTF18abjrfqx!
# Saved results for ZTF18abjrfqx!
#
# Not enough obs for ZTF18abiirfq. pass!
#
# Extracted LC features for ZTF18abimhfu!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18abimhfu!
#
# Extracted LC features for ZTF18abjgyyr!
# Saved results for ZTF18abjgyyr!
#
# Extracted LC features for ZTF18abgrbjb!
# Saved results for ZTF18abgrbjb!
# Extracted LC features for ZTF18abhxidv!
# Saved results for ZTF18abhxidv!
#
# Extracted LC features for ZTF18abfwuwn!
# Saved results for ZTF18abfwuwn!
#
# Extracted LC features for ZTF18abixkjh!
# Saved results for ZTF18abixkjh!
#
# Extracted LC features for ZTF18aailmnv!
# Some features are NaN for ZTF18aailmnv. Skip!
#
# Extracted LC features for ZTF18abeegsl!
# Saved results for ZTF18abeegsl!
#
# Extracted LC features for ZTF18abfgygp!
# Saved results for ZTF18abfgygp!
#
# Extracted LC features for ZTF18abdkimx!
# Saved results for ZTF18abdkimx!
#
# Extracted LC features for ZTF18aansqun!
# Saved results for ZTF18aansqun!
#
# Extracted LC features for ZTF18abddrhd!
# Some features are NaN for ZTF18abddrhd. Skip!
#
# Extracted LC features for ZTF18abesqnb!
# Saved results for ZTF18abesqnb!
#
# Extracted LC features for ZTF18abespgb!
# Saved results for ZTF18abespgb!
#
# Extracted LC features for ZTF18abetewu!
# Saved results for ZTF18abetewu!
#
# Extracted LC features for ZTF18abcyilc!
# Saved results for ZTF18abcyilc!
#
# Not enough obs for ZTF18abetejo. pass!
#
# Extracted LC features for ZTF18abetehf!
# Saved results for ZTF18abetehf!
#
# Extracted LC features for ZTF18abeaipj!
# Saved results for ZTF18abeaipj!
#
# Extracted LC features for ZTF18abdrmin!
# Saved results for ZTF18abdrmin!
#
# Extracted LC features for ZTF18abcysdx!
# Saved results for ZTF18abcysdx!
#
# Extracted LC features for ZTF18abdefet!
# Saved results for ZTF18abdefet!
#
# Extracted LC features for ZTF18abdmlya!
# Saved results for ZTF18abdmlya!
#
# Extracted LC features for ZTF18abdiqdh!
# Saved results for ZTF18abdiqdh!
#
# Extracted LC features for ZTF18abdiwpt!
# Saved results for ZTF18abdiwpt!
#
# 900
# Extracted LC features for ZTF18abcvush!
# Saved results for ZTF18abcvush!
#
# Extracted LC features for ZTF18abdgwxn!
# Saved results for ZTF18abdgwxn!
#
# Extracted LC features for ZTF18abdffeo!
# Some features are NaN for ZTF18abdffeo. Skip!
#
# Extracted LC features for ZTF18abdfazk!
# Saved results for ZTF18abdfazk!
#
# Extracted LC features for ZTF18abdbuty!
# Saved results for ZTF18abdbuty!
#
# Extracted LC features for ZTF18abcecfi!
# Saved results for ZTF18abcecfi!
#
# Extracted LC features for ZTF18abcezmh!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18abcezmh!
#
# Extracted LC features for ZTF18abdfaqi!
# Saved results for ZTF18abdfaqi!
#
# Extracted LC features for ZTF18abcsgvj!
# Saved results for ZTF18abcsgvj!
#
# Extracted LC features for ZTF18abclfee!
# Saved results for ZTF18abclfee!
#
# No obs for ZTF18abdcfgz. pass!
#
# Extracted LC features for ZTF18abcrzfz!
# Saved results for ZTF18abcrzfz!
#
# Extracted LC features for ZTF18abcrxoj!
# Saved results for ZTF18abcrxoj!
#
# No obs for ZTF18abcryxz. pass!
#
# Extracted LC features for ZTF18abcrtnq!
# Saved results for ZTF18abcrtnq!
#
# Extracted LC features for ZTF18abckujg!
# Some features are NaN for ZTF18abckujg. Skip!
#
# Extracted LC features for ZTF18abcicrq!
# Saved results for ZTF18abcicrq!
#
# Extracted LC features for ZTF18abbpeqo!
# Saved results for ZTF18abbpeqo!
#
# Extracted LC features for ZTF18abceakp!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18abceakp!
#
# No obs for ZTF18abcpolh. pass!
#
# Extracted LC features for ZTF18abckujq!
# Saved results for ZTF18abckujq!
#
# Extracted LC features for ZTF18abbovuc!
# Saved results for ZTF18abbovuc!
#
# Extracted LC features for ZTF18aayidfz!
# Saved results for ZTF18aayidfz!
#
# No obs for ZTF18aayiahw. pass!
#
# Extracted LC features for ZTF18aayivxm!
# Saved results for ZTF18aayivxm!
#
# Extracted LC features for ZTF18abbvsiv!
# Saved results for ZTF18abbvsiv!
#
# Extracted LC features for ZTF18abaxlpi!
# Saved results for ZTF18abaxlpi!
#
# Extracted LC features for ZTF18aazjztm!
# Saved results for ZTF18aazjztm!
#
# Extracted LC features for ZTF18aazabmh!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 0.0% of events.
# Some features are NaN for ZTF18aazabmh. Skip!
#
# Extracted LC features for ZTF18abadjhx!
# Saved results for ZTF18abadjhx!
#
# Extracted LC features for ZTF18aazsabq!
# Saved results for ZTF18aazsabq!
#
# Extracted LC features for ZTF18aaykjei!
# Saved results for ZTF18aaykjei!
#
# Extracted LC features for ZTF18aaytovs!
# Saved results for ZTF18aaytovs!
#
# Extracted LC features for ZTF18aazcoob!
# Saved results for ZTF18aazcoob!
#
# Extracted LC features for ZTF18aazblzy!
# Saved results for ZTF18aazblzy!
#
# Extracted LC features for ZTF18aazixbw!
# Saved results for ZTF18aazixbw!
#
# Extracted LC features for ZTF18aaydmkh!
# Saved results for ZTF18aaydmkh!
#
# Extracted LC features for ZTF18aaxvpsw!
# Saved results for ZTF18aaxvpsw!
#
# Extracted LC features for ZTF18aaxwjmp!
# Saved results for ZTF18aaxwjmp!
#
# Extracted LC features for ZTF18aayjyub!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18aayjyub!
#
# Extracted LC features for ZTF18aayxupv!
# Saved results for ZTF18aayxupv!
#
# Extracted LC features for ZTF18aaxqyki!
# Found no hosts in GLADE.
# Finding northern sources with Pan-starrs...
# Found matches for 50.0% of events.
# Saved results for ZTF18aaxqyki!
#
# Extracted LC features for ZTF18aayjvve!
# Saved results for ZTF18aayjvve!
#
# No obs for ZTF18aaykmzg. pass!
#
# Extracted LC features for ZTF18aawpcel!
# Saved results for ZTF18aawpcel!
#
# Extracted LC features for ZTF18aaxnkos!
# Saved results for ZTF18aaxnkos!
#
# Extracted LC features for ZTF18aaxkfos!
# Saved results for ZTF18aaxkfos!
#
# Extracted LC features for ZTF18aavrzxp!
# Saved results for ZTF18aavrzxp!
#
# Extracted LC features for ZTF18aaxdrjn!
# Saved results for ZTF18aaxdrjn!
#
# Extracted LC features for ZTF18aaxcxih!
# Saved results for ZTF18aaxcxih!
#
# 950
# Extracted LC features for ZTF18aaxavsk!
# Saved results for ZTF18aaxavsk!
#
# Extracted LC features for ZTF18aaxcntm!
# Saved results for ZTF18aaxcntm!
#
# Extracted LC features for ZTF18aawjywv!
# Saved results for ZTF18aawjywv!
#
# Extracted LC features for ZTF18aaqqoqs!
# Saved results for ZTF18aaqqoqs!
#
# Extracted LC features for ZTF18aataafd!
# Saved results for ZTF18aataafd!
#
# Extracted LC features for ZTF18aarxzmv!
# Some features are NaN for ZTF18aarxzmv. Skip!
#
# Extracted LC features for ZTF18aavnvmp!
# Saved results for ZTF18aavnvmp!
#
# Extracted LC features for ZTF18aatzygk!
# Saved results for ZTF18aatzygk!
#
# Not enough obs for ZTF18aarbify. pass!
#
# Extracted LC features for ZTF18aaqehoc!
# Saved results for ZTF18aaqehoc!
#
# No obs for ZTF18aahmrtf. pass!
#
# CPU times: user 31min 45s, sys: 2min 48s, total: 34min 34s
# Wall time: 2h 1min 44s

# %%
keep_tns_result_df.iloc[1166:1170]
# Out:
#                       RA           DEC Obj. Type  Redshift  \
# Name
# SN 2019qky  00:19:53.090  -23:23:51.68     SN Ia    0.0460
# SN 2019qjj  00:36:01.664  -05:23:01.98     SN Ia    0.0680
# AT 2019qiz  04:46:37.880  -10:13:34.90       TDE    0.0151
# SN 2019qij  08:21:37.457  +40:51:48.54     SN II    0.1066
#
#                           Host Name  Host Redshift  \
# Name
# SN 2019qky  2MASX J00195288-2323393       0.063454
# SN 2019qjj                      NaN            NaN
# AT 2019qiz  2MASX J04463790-1013349       0.015130
# SN 2019qij                      NaN            NaN
#
#                                      Reporting Group/s  \
# Name
# SN 2019qky  ALeRCE, ZTF, Pan-STARRS, ATLAS, GaiaAlerts
# SN 2019qjj                                         ZTF
# AT 2019qiz  ALeRCE, ZTF, ATLAS, GaiaAlerts, Pan-STARRS
# SN 2019qij                                  ZTF, ATLAS
#
#                        Discovery Data Source/s Classifying Group/s  \
# Name
# SN 2019qky  ZTF, Pan-STARRS, ATLAS, GaiaAlerts                 ZTF
# SN 2019qjj                                 ZTF                 ZTF
# AT 2019qiz  ZTF, ATLAS, GaiaAlerts, Pan-STARRS                None
# SN 2019qij                          ZTF, ATLAS                 ZTF
#
#                                     Associated Group/s  ... Public  \
# Name                                                    ...
# SN 2019qky  ALeRCE; ATLAS; GaiaAlerts; Pan-STARRS; ZTF  ...      1
# SN 2019qjj                                         ZTF  ...      1
# AT 2019qiz  ALeRCE; ATLAS; GaiaAlerts; Pan-STARRS; ZTF  ...      1
# SN 2019qij                                  ATLAS; ZTF  ...      1
#
#            End Prop. Period Discovery Mag/Flux  Discovery Filter  \
# Name
# SN 2019qky              NaN            18.7590             g-ZTF
# SN 2019qjj              NaN            18.7500             g-ZTF
# AT 2019qiz              NaN            17.8184             r-ZTF
# SN 2019qij              NaN            19.4000             r-ZTF
#
#                 Discovery Date (UT)         Sender  Remarks  \
# Name
# SN 2019qky  2019-09-20 09:02:40.000         ALeRCE      NaN
# SN 2019qjj  2019-09-17 09:05:17.000  ZTF_AMPEL_NEW      NaN
# AT 2019qiz  2019-09-19 11:59:43.000         ALeRCE      NaN
# SN 2019qij  2019-09-19 11:41:13.000  ZTF_AMPEL_NEW      NaN
#
#               Discovery Bibcode Classification Bibcodes Ext. catalog/s
# Name
# SN 2019qky  2019TNSTR1865....1F     2019TNSCR1923....1F            NaN
# SN 2019qjj  2019TNSTR1872....1N     2020TNSCR.601....1D            NaN
# AT 2019qiz  2019TNSTR1857....1F     2019TNSCR1921....1S            NaN
# SN 2019qij  2019TNSTR1863....1N     2020TNSCR1935....1D            NaN
#
# [4 rows x 24 columns]

# %% [markdown]
# ## Load pickle

# %%
figure_path = f"/Users/patrickaleo/Desktop/Illinois/LAISS-antares/repo/RFC/SMOTE_train_test_70-30_min14_kneighbors8/cls=binary_n_estimators={n_estimators}_max_depth={max_depth}_rs={random_state}_max_feats={max_features}_cw=balanced/figures"
model_path = f"/Users/patrickaleo/Desktop/Illinois/LAISS-antares/repo/RFC/SMOTE_train_test_70-30_min14_kneighbors8/cls=binary_n_estimators={n_estimators}_max_depth={max_depth}_rs={random_state}_max_feats={max_features}_cw=balanced/model"
if not os.path.exists(figure_path):
    os.makedirs(figure_path)
    
if not os.path.exists(model_path):
    os.makedirs(model_path)

cm_path = f"{figure_path}/confusion_matrix/"
if not os.path.exists(cm_path):
    os.makedirs(cm_path)

# %%
n_estimators=100 #3500
max_depth=35 #35
random_state=11
max_features=35 # {“sqrt”, “log2”, None}, int or float, default=”sqrt” - sqrt(120) ~ 10
#class_weight={"None": 1, "SLSN-II": 1, "SN II": 1, 'SN IIP': 1, 'SN IIb': 1, 'SN IIn': 1, 'SN Ia': 1,
#       'SN Ia-91T-like': 1, 'SN Ib': 1, 'SN Ic': 1, 'SN Ic-BL': 1, 'TDE': 1} #"balanced"
class_weight={"Normal": 1, "Other": 1} #"balanced"

with open(f'{model_path}/cls=binary_n_estimators={n_estimators}_max_depth={max_depth}_rs={random_state}_max_feats={max_features}_cw=balanced.pkl', 'rb') as f:
    clf = pickle.load(f)

# %%
# Predict Excluded Object
predicted_probability = 100 * clf.predict_proba(x_test)

# %%
#clf.classes_[1:]
clf.classes_

# %%
# Create a dataframe from the arrays
df = pd.DataFrame(predicted_probability, columns=clf.classes_)
df = df.set_index(x_test_all.index)

# Add a new column "RFC_best_cls" to the existing dataframe that contains the class label with the highest probability per row
# clf.classes_[1:] and row.values[1:] ignores the None class
#df['RFC_best_cls'] = df.apply(lambda row: clf.classes_[1:][np.argmax(row.values[1:])], axis=1)
# USE clf.classes_ and row.values if you don't train on the None class
df['RFC_best_cls'] = df.apply(lambda row: clf.classes_[np.argmax(row.values)], axis=1)
df

# %%
df2 = pd.concat([x_test_all, df], axis=1)
df2 = df2.replace({"tns_cls": di})
df2

# %%
# Confusion matrices
title='RFC'
df = df2
true_labels = np.array(df['tns_cls'])
predicted_labels = np.array(df['RFC_best_cls'])#np.array(df['most_common_cls_ann=1-100']) # np.array(df['ann=1_tns_cls'])
# define the class labels
class_names = np.unique(true_labels)
nclasses = len(class_names)

KINDS = ['completeness', 'purity']
for KIND in KINDS:
    # Sims test set
    plot_conf_matrix(true_labels, predicted_labels, labels=class_names, 
             title=f'{title} ({KIND})', kind=KIND)
    plt.savefig(f'{cm_path}/confmatrix_before_lc_feature_extractor_{title}_{KIND}.jpg', dpi=300, bbox_inches='tight')
    plt.show()
    plt.close()
